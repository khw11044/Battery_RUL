# %%
import random
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn 
import torch.optim as optim

from sklearn.model_selection import train_test_split
from sklearn.metrics import * 
from tqdm import tqdm 

import warnings
warnings.filterwarnings("ignore")

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42) # Seed 고정

# %%
def RUL_metric(y_valid, y_pred, threshold=10):

    error = y_valid.reshape(-1) - y_pred.reshape(-1)
    per = np.where(error<=threshold, 1, 0)
    
    return sum(per) / len(per)

# %%
# sns.set()

# %%
path = "data/Battery_RUL.csv"

# %%
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    Cycle_Index  Discharge Time (s)  Decrement 3.6-3.4V (s)  \
# 0          1.0             2595.30             1151.488500
# 1          2.0             7408.64             1172.512500
# 2          3.0             7393.76             1112.992000
# 3          4.0             7385.50             1080.320667
# 4          6.0            65022.75            29813.487000
#
#    Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)  \
# 0                      3.670                    3.211           5460.001
# 1                      4.246                    3.220           5508.992
# 2                      4.249                    3.224           5508.993
# 3                      4.250                    3.225           5502.016
# 4                      4.290                    3.398           5480.992
#
#    Time constant current (s)  Charging time (s)   RUL
# 0                    6755.01           10777.82  1112
# 1                    6762.02           10500.35  1111
# 2                    6762.02           10420.38  1110
# 3                    6762.02           10322.81  1109
# 4                   53213.54           56699.65  1107

# %%
data.shape
# Out:
# (15064, 9)

# %%
# 다음 컬럼들은 RUL에 관계가 없기 때문에 제거한다.
data=data.drop(['Cycle_Index','Discharge Time (s)', 'Decrement 3.6-3.4V (s)', 'Time constant current (s)','Charging time (s)'],axis=1)

# %%
data.head()
# Out:
#    Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)   RUL
# 0                      3.670                    3.211           5460.001  1112
# 1                      4.246                    3.220           5508.992  1111
# 2                      4.249                    3.224           5508.993  1110
# 3                      4.250                    3.225           5502.016  1109
# 4                      4.290                    3.398           5480.992  1107

# %% [markdown]
# ## Modeling and Predections

# %%
data = data[data['RUL']!=0]

X = data.drop(['RUL'], axis=1)
y = data['RUL']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=2023, shuffle =True)
X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size=0.2, random_state=2023, shuffle =True)

# %%
class Pipeline:
    def __init__(self, scalar):
        self.scalar = scalar
    
    def fit(self, X, y):
        X = self.scalar.fit_transform(X)
        return X, y.to_numpy(dtype=np.float32)
    
    def transform(self, X, y):
        X = self.scalar.transform(X)
        return X, y.to_numpy(dtype=np.float32)

# %%
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler
# 실험상 RobustScaler 또는 StandardScaler가 성능이 가장 낮다 
robust = RobustScaler()
pipeline = Pipeline(robust)

# %%
X_train_s, y_train_s = pipeline.fit(X_train, y_train)

X_val_s, y_val_s = pipeline.transform(X_val, y_val)
X_test_s, y_test_s = pipeline.transform(X_test, y_test)

# %%
X_train_s = torch.FloatTensor(X_train_s)
y_train_s = torch.FloatTensor(y_train_s).unsqueeze(-1)

X_val_s = torch.FloatTensor(X_val_s)
y_val_s = torch.FloatTensor(y_val_s).unsqueeze(-1)

X_test_s = torch.FloatTensor(X_test_s)
y_test_s = torch.FloatTensor(y_test_s).unsqueeze(-1)

# %%
X_train_s.shape, y_train_s.shape, X_val_s.shape, y_val_s.shape, X_test_s.shape, y_test_s.shape
# Out:
# (torch.Size([10535, 3]),
#  torch.Size([10535, 1]),
#  torch.Size([3612, 3]),
#  torch.Size([3612, 1]),
#  torch.Size([903, 3]),
#  torch.Size([903, 1]))

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.l1 = nn.Linear(input_size, hidden_size)
        self.l2 = nn.Linear(hidden_size, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        return out

# %%
input_size =  X_train_s.shape[1] #num of columns
hidden_size = 16
num_classes = 1

model = NeuralNet(input_size, hidden_size, num_classes)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.1, weight_decay=1e-5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min')

# %%
train_loss_list = []
test_loss_list = []
min_diff_dict = {}

targets_list = []
pred_list = []
epoch_list = []
MAE_list= []
RUL_score_list = []
best_MAE = np.inf
best_model = 0
# for epoch in tqdm(range(1, 101)):
for epoch in range(1, 101):
    model.train()
    size = len(X_train_s)
    optimizer.zero_grad()
    outputs = model(X_train_s)
    loss = criterion(outputs, y_train_s)
    loss.backward()
    optimizer.step()
    print(f'Epoch : {epoch} / AVG train loss : {loss.item()/size}')
    train_loss_list.append(loss.item()/size)
    
    model.eval()
    with torch.no_grad():
        size = len(X_val_s)
        pred = model(X_val_s)
        test_loss = criterion(pred, y_val_s)
        
        test_loss_list.append(test_loss.item()/size)
        pred_np = pred.squeeze().tolist()
        target_np = y_val_s.squeeze().tolist()
        
        try:
            for i,j in zip(pred_np,target_np):
                pred_list.append(i)
                targets_list.append(j)
        except:
            pass
        
        pred = pred.detach().cpu().numpy()
        y = y_val_s.detach().cpu().numpy()
    
        RMSE = mean_squared_error(y, pred, squared=False)
        MAE = mean_absolute_error(y, pred)
        MAPE = mean_absolute_percentage_error(y, pred)
        R2 = r2_score(y, pred)
        RUL_score = RUL_metric(y, pred, threshold=100)
        msg = f"Test: \n Avg loss: {test_loss.item()/size:>8f}, \n"
        print(msg) 
        msg = f"- RMSE: {(RMSE):>0.2f}, - MAE: {(MAE):>0.2f}, - MAPE: {(MAPE):>0.2f},  - R2: {(R2):>0.2f},  - RUL_metric: {(RUL_score):>0.2f}, \n"
        print(msg)
        print('---'*20)
        
        scheduler.step(test_loss)

    epoch_list.append(epoch)
    MAE_list.append(MAE)
    RUL_score_list.append(RUL_score*100)
    
    mean_MAE = np.mean(MAE_list)
    if mean_MAE < best_MAE:
        best_MAE = mean_MAE
        best_model = model
    
plt.figure(figsize=(10,8))
plt.subplot(3,1,1)
plt.scatter(targets_list, pred_list)
plt.xlabel('Target', fontsize=10)
plt.ylabel('Prediction', fontsize=10)
plt.ylim(0, 1300)
plt.title(f"Epoch {epoch+1}", fontsize=13)

plt.subplot(3,1,2)
# plt.scatter(epoch_list, MAE_list)
plt.plot(MAE_list, label='RUL_score', marker = '.')
plt.ylim(0, 1000)
plt.xlabel('Epoch')
plt.ylabel('Target-Pred MAE')

# PLOT Difference
plt.subplot(3,1,3)
# plt.scatter(epoch_list, RUL_score_list)
plt.plot(RUL_score_list, label='RUL_score', marker = '.')
plt.ylim(0, 100)
plt.xlabel('Epoch')
plt.ylabel('Target-Pred RUL_score (%)')
# plt.scatter(epoch, test_loss)
plt.tight_layout()

plt.savefig(f'./result/training_{epoch}.png')
# Out:
# Epoch : 1 / AVG train loss : 39.03604947793071
# Test:
#  Avg loss: 113.333679,
#
# - RMSE: 639.81, - MAE: 554.08, - MAPE: 1.00,  - R2: -3.00,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 2 / AVG train loss : 38.9515810393925
# Test:
#  Avg loss: 113.086413,
#
# - RMSE: 639.12, - MAE: 553.32, - MAPE: 0.99,  - R2: -2.99,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 3 / AVG train loss : 38.85890187470337
# Test:
#  Avg loss: 112.778957,
#
# - RMSE: 638.25, - MAE: 552.41, - MAPE: 0.99,  - R2: -2.98,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 4 / AVG train loss : 38.744313597532035
# Test:
#  Avg loss: 112.402824,
#
# - RMSE: 637.18, - MAE: 551.30, - MAPE: 0.98,  - R2: -2.97,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 5 / AVG train loss : 38.60486770289511
# Test:
#  Avg loss: 111.946342,
#
# - RMSE: 635.89, - MAE: 549.95, - MAPE: 0.98,  - R2: -2.95,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 6 / AVG train loss : 38.43624228761272
# Test:
#  Avg loss: 111.396699,
#
# - RMSE: 634.32, - MAE: 548.33, - MAPE: 0.98,  - R2: -2.93,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 7 / AVG train loss : 38.23426969625059
# Test:
#  Avg loss: 110.742819,
#
# - RMSE: 632.46, - MAE: 546.42, - MAPE: 0.97,  - R2: -2.91,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 8 / AVG train loss : 37.99571962505932
# Test:
#  Avg loss: 109.978622,
#
# - RMSE: 630.27, - MAE: 544.23, - MAPE: 0.97,  - R2: -2.88,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 9 / AVG train loss : 37.719203844328426
# Test:
#  Avg loss: 109.090921,
#
# - RMSE: 627.72, - MAE: 541.69, - MAPE: 0.97,  - R2: -2.85,  - RUL_metric: 0.10,
#
# ------------------------------------------------------------
# Epoch : 10 / AVG train loss : 37.40122211675368
# Test:
#  Avg loss: 108.079501,
#
# - RMSE: 624.81, - MAE: 538.80, - MAPE: 0.97,  - R2: -2.82,  - RUL_metric: 0.10,
#
# ------------------------------------------------------------
# Epoch : 11 / AVG train loss : 37.043070716658754
# Test:
#  Avg loss: 106.940295,
#
# - RMSE: 621.50, - MAE: 535.54, - MAPE: 0.97,  - R2: -2.78,  - RUL_metric: 0.10,
#
# ------------------------------------------------------------
# Epoch : 12 / AVG train loss : 36.64488312766967
# Test:
#  Avg loss: 105.673441,
#
# - RMSE: 617.81, - MAE: 532.03, - MAPE: 0.97,  - R2: -2.73,  - RUL_metric: 0.11,
#
# ------------------------------------------------------------
# Epoch : 13 / AVG train loss : 36.20959302325581
# Test:
#  Avg loss: 104.279693,
#
# - RMSE: 613.72, - MAE: 528.20, - MAPE: 0.97,  - R2: -2.68,  - RUL_metric: 0.11,
#
# ------------------------------------------------------------
# Epoch : 14 / AVG train loss : 35.74044257237779
# Test:
#  Avg loss: 102.764898,
#
# - RMSE: 609.25, - MAE: 524.10, - MAPE: 0.97,  - R2: -2.63,  - RUL_metric: 0.12,
#
# ------------------------------------------------------------
# Epoch : 15 / AVG train loss : 35.24269399620313
# Test:
#  Avg loss: 101.134638,
#
# - RMSE: 604.40, - MAE: 519.68, - MAPE: 0.98,  - R2: -2.57,  - RUL_metric: 0.12,
#
# ------------------------------------------------------------
# Epoch : 16 / AVG train loss : 34.72095989558614
# Test:
#  Avg loss: 99.400825,
#
# - RMSE: 599.20, - MAE: 515.04, - MAPE: 0.98,  - R2: -2.51,  - RUL_metric: 0.12,
#
# ------------------------------------------------------------
# Epoch : 17 / AVG train loss : 34.181217370669195
# Test:
#  Avg loss: 97.577865,
#
# - RMSE: 593.68, - MAE: 510.16, - MAPE: 0.99,  - R2: -2.45,  - RUL_metric: 0.13,
#
# ------------------------------------------------------------
# Epoch : 18 / AVG train loss : 33.628868058851445
# Test:
#  Avg loss: 95.685173,
#
# - RMSE: 587.89, - MAE: 505.08, - MAPE: 1.00,  - R2: -2.38,  - RUL_metric: 0.13,
#
# ------------------------------------------------------------
# Epoch : 19 / AVG train loss : 33.06848006644518
# Test:
#  Avg loss: 93.733484,
#
# - RMSE: 581.86, - MAE: 499.89, - MAPE: 1.01,  - R2: -2.31,  - RUL_metric: 0.13,
#
# ------------------------------------------------------------
# Epoch : 20 / AVG train loss : 32.49760026103465
# Test:
#  Avg loss: 91.725100,
#
# - RMSE: 575.60, - MAE: 494.32, - MAPE: 1.02,  - R2: -2.24,  - RUL_metric: 0.14,
#
# ------------------------------------------------------------
# Epoch : 21 / AVG train loss : 31.907839938300903
# Test:
#  Avg loss: 89.651232,
#
# - RMSE: 569.05, - MAE: 488.37, - MAPE: 1.03,  - R2: -2.17,  - RUL_metric: 0.14,
#
# ------------------------------------------------------------
# Epoch : 22 / AVG train loss : 31.286933436165164
# Test:
#  Avg loss: 87.499282,
#
# - RMSE: 562.18, - MAE: 482.03, - MAPE: 1.05,  - R2: -2.09,  - RUL_metric: 0.15,
#
# ------------------------------------------------------------
# Epoch : 23 / AVG train loss : 30.62418723303275
# Test:
#  Avg loss: 85.257164,
#
# - RMSE: 554.93, - MAE: 475.31, - MAPE: 1.06,  - R2: -2.01,  - RUL_metric: 0.15,
#
# ------------------------------------------------------------
# Epoch : 24 / AVG train loss : 29.91264534883721
# Test:
#  Avg loss: 82.914132,
#
# - RMSE: 547.25, - MAE: 468.26, - MAPE: 1.08,  - R2: -1.93,  - RUL_metric: 0.16,
#
# ------------------------------------------------------------
# Epoch : 25 / AVG train loss : 29.148163858566683
# Test:
#  Avg loss: 80.463533,
#
# - RMSE: 539.11, - MAE: 460.83, - MAPE: 1.10,  - R2: -1.84,  - RUL_metric: 0.16,
#
# ------------------------------------------------------------
# Epoch : 26 / AVG train loss : 28.328687114380635
# Test:
#  Avg loss: 77.899372,
#
# - RMSE: 530.45, - MAE: 453.00, - MAPE: 1.12,  - R2: -1.75,  - RUL_metric: 0.17,
#
# ------------------------------------------------------------
# Epoch : 27 / AVG train loss : 27.452690436639774
# Test:
#  Avg loss: 75.221198,
#
# - RMSE: 521.25, - MAE: 444.76, - MAPE: 1.15,  - R2: -1.66,  - RUL_metric: 0.18,
#
# ------------------------------------------------------------
# Epoch : 28 / AVG train loss : 26.52004330802088
# Test:
#  Avg loss: 72.432672,
#
# - RMSE: 511.49, - MAE: 436.13, - MAPE: 1.17,  - R2: -1.56,  - RUL_metric: 0.18,
#
# ------------------------------------------------------------
# Epoch : 29 / AVG train loss : 25.533504390128144
# Test:
#  Avg loss: 69.539954,
#
# - RMSE: 501.18, - MAE: 427.08, - MAPE: 1.20,  - R2: -1.46,  - RUL_metric: 0.19,
#
# ------------------------------------------------------------
# Epoch : 30 / AVG train loss : 24.497368889416233
# Test:
#  Avg loss: 66.551577,
#
# - RMSE: 490.29, - MAE: 417.63, - MAPE: 1.22,  - R2: -1.35,  - RUL_metric: 0.20,
#
# ------------------------------------------------------------
# Epoch : 31 / AVG train loss : 23.417244601328903
# Test:
#  Avg loss: 63.481459,
#
# - RMSE: 478.85, - MAE: 407.81, - MAPE: 1.25,  - R2: -1.24,  - RUL_metric: 0.20,
#
# ------------------------------------------------------------
# Epoch : 32 / AVG train loss : 22.303796867584243
# Test:
#  Avg loss: 60.348686,
#
# - RMSE: 466.88, - MAE: 397.61, - MAPE: 1.28,  - R2: -1.13,  - RUL_metric: 0.21,
#
# ------------------------------------------------------------
# Epoch : 33 / AVG train loss : 21.173838692453725
# Test:
#  Avg loss: 57.167861,
#
# - RMSE: 454.41, - MAE: 386.98, - MAPE: 1.31,  - R2: -1.02,  - RUL_metric: 0.22,
#
# ------------------------------------------------------------
# Epoch : 34 / AVG train loss : 20.034938597532037
# Test:
#  Avg loss: 53.948427,
#
# - RMSE: 441.43, - MAE: 375.95, - MAPE: 1.33,  - R2: -0.91,  - RUL_metric: 0.22,
#
# ------------------------------------------------------------
# Epoch : 35 / AVG train loss : 18.887936046511626
# Test:
#  Avg loss: 50.702502,
#
# - RMSE: 427.95, - MAE: 364.49, - MAPE: 1.36,  - R2: -0.79,  - RUL_metric: 0.23,
#
# ------------------------------------------------------------
# Epoch : 36 / AVG train loss : 17.734477337446606
# Test:
#  Avg loss: 47.450906,
#
# - RMSE: 414.00, - MAE: 352.62, - MAPE: 1.38,  - R2: -0.68,  - RUL_metric: 0.24,
#
# ------------------------------------------------------------
# Epoch : 37 / AVG train loss : 16.586774738965353
# Test:
#  Avg loss: 44.203449,
#
# - RMSE: 399.58, - MAE: 340.34, - MAPE: 1.40,  - R2: -0.56,  - RUL_metric: 0.25,
#
# ------------------------------------------------------------
# Epoch : 38 / AVG train loss : 15.450571013289036
# Test:
#  Avg loss: 40.970896,
#
# - RMSE: 384.69, - MAE: 327.67, - MAPE: 1.42,  - R2: -0.45,  - RUL_metric: 0.25,
#
# ------------------------------------------------------------
# Epoch : 39 / AVG train loss : 14.32516166350261
# Test:
#  Avg loss: 37.766702,
#
# - RMSE: 369.34, - MAE: 314.59, - MAPE: 1.44,  - R2: -0.33,  - RUL_metric: 0.26,
#
# ------------------------------------------------------------
# Epoch : 40 / AVG train loss : 13.216075878025629
# Test:
#  Avg loss: 34.604941,
#
# - RMSE: 353.54, - MAE: 301.13, - MAPE: 1.45,  - R2: -0.22,  - RUL_metric: 0.27,
#
# ------------------------------------------------------------
# Epoch : 41 / AVG train loss : 12.128711586378737
# Test:
#  Avg loss: 31.508063,
#
# - RMSE: 337.35, - MAE: 287.39, - MAPE: 1.46,  - R2: -0.11,  - RUL_metric: 0.28,
#
# ------------------------------------------------------------
# Epoch : 42 / AVG train loss : 11.071699246559088
# Test:
#  Avg loss: 28.494443,
#
# - RMSE: 320.81, - MAE: 273.41, - MAPE: 1.47,  - R2: -0.01,  - RUL_metric: 0.30,
#
# ------------------------------------------------------------
# Epoch : 43 / AVG train loss : 10.04765439606075
# Test:
#  Avg loss: 25.583519,
#
# - RMSE: 303.99, - MAE: 259.18, - MAPE: 1.47,  - R2: 0.10,  - RUL_metric: 0.30,
#
# ------------------------------------------------------------
# Epoch : 44 / AVG train loss : 9.061742109634551
# Test:
#  Avg loss: 22.798142,
#
# - RMSE: 286.96, - MAE: 244.62, - MAPE: 1.47,  - R2: 0.19,  - RUL_metric: 0.32,
#
# ------------------------------------------------------------
# Epoch : 45 / AVG train loss : 8.119867554579972
# Test:
#  Avg loss: 20.161629,
#
# - RMSE: 269.86, - MAE: 229.75, - MAPE: 1.47,  - R2: 0.29,  - RUL_metric: 0.34,
#
# ------------------------------------------------------------
# Epoch : 46 / AVG train loss : 7.229592578310394
# Test:
#  Avg loss: 17.699642,
#
# - RMSE: 252.85, - MAE: 214.57, - MAPE: 1.47,  - R2: 0.37,  - RUL_metric: 0.36,
#
# ------------------------------------------------------------
# Epoch : 47 / AVG train loss : 6.3985442869008065
# Test:
#  Avg loss: 15.436646,
#
# - RMSE: 236.13, - MAE: 199.22, - MAPE: 1.46,  - R2: 0.45,  - RUL_metric: 0.38,
#
# ------------------------------------------------------------
# Epoch : 48 / AVG train loss : 5.635362037256763
# Test:
#  Avg loss: 13.392854,
#
# - RMSE: 219.94, - MAE: 183.77, - MAPE: 1.44,  - R2: 0.53,  - RUL_metric: 0.40,
#
# ------------------------------------------------------------
# Epoch : 49 / AVG train loss : 4.947260619364025
# Test:
#  Avg loss: 11.583875,
#
# - RMSE: 204.55, - MAE: 168.30, - MAPE: 1.43,  - R2: 0.59,  - RUL_metric: 0.42,
#
# ------------------------------------------------------------
# Epoch : 50 / AVG train loss : 4.339082151756052
# Test:
#  Avg loss: 10.015469,
#
# - RMSE: 190.20, - MAE: 152.89, - MAPE: 1.41,  - R2: 0.65,  - RUL_metric: 0.47,
#
# ------------------------------------------------------------
# Epoch : 51 / AVG train loss : 3.813295710726151
# Test:
#  Avg loss: 8.687080,
#
# - RMSE: 177.14, - MAE: 137.69, - MAPE: 1.38,  - R2: 0.69,  - RUL_metric: 0.54,
#
# ------------------------------------------------------------
# Epoch : 52 / AVG train loss : 3.3695531264831513
# Test:
#  Avg loss: 7.591585,
#
# - RMSE: 165.59, - MAE: 123.14, - MAPE: 1.36,  - R2: 0.73,  - RUL_metric: 0.62,
#
# ------------------------------------------------------------
# Epoch : 53 / AVG train loss : 3.005797453429046
# Test:
#  Avg loss: 6.715534,
#
# - RMSE: 155.75, - MAE: 110.31, - MAPE: 1.33,  - R2: 0.76,  - RUL_metric: 0.70,
#
# ------------------------------------------------------------
# Epoch : 54 / AVG train loss : 2.717550686699098
# Test:
#  Avg loss: 6.045446,
#
# - RMSE: 147.77, - MAE: 100.25, - MAPE: 1.31,  - R2: 0.79,  - RUL_metric: 0.77,
#
# ------------------------------------------------------------
# Epoch : 55 / AVG train loss : 2.499902112007594
# Test:
#  Avg loss: 5.587538,
#
# - RMSE: 142.06, - MAE: 92.83, - MAPE: 1.28,  - R2: 0.80,  - RUL_metric: 0.80,
#
# ------------------------------------------------------------
# Epoch : 56 / AVG train loss : 2.3525697451945895
# Test:
#  Avg loss: 5.323059,
#
# - RMSE: 138.66, - MAE: 88.98, - MAPE: 1.26,  - R2: 0.81,  - RUL_metric: 0.83,
#
# ------------------------------------------------------------
# Epoch : 57 / AVG train loss : 2.2692427770526815
# Test:
#  Avg loss: 5.195816,
#
# - RMSE: 136.99, - MAE: 89.96, - MAPE: 1.24,  - R2: 0.82,  - RUL_metric: 0.84,
#
# ------------------------------------------------------------
# Epoch : 58 / AVG train loss : 2.232950433080209
# Test:
#  Avg loss: 5.173291,
#
# - RMSE: 136.70, - MAE: 93.59, - MAPE: 1.22,  - R2: 0.82,  - RUL_metric: 0.85,
#
# ------------------------------------------------------------
# Epoch : 59 / AVG train loss : 2.232515869719981
# Test:
#  Avg loss: 5.226477,
#
# - RMSE: 137.40, - MAE: 97.72, - MAPE: 1.21,  - R2: 0.82,  - RUL_metric: 0.85,
#
# ------------------------------------------------------------
# Epoch : 60 / AVG train loss : 2.257987511865211
# Test:
#  Avg loss: 5.346201,
#
# - RMSE: 138.96, - MAE: 101.51, - MAPE: 1.19,  - R2: 0.81,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------
# Epoch : 61 / AVG train loss : 2.3036600468675843
# Test:
#  Avg loss: 5.478647,
#
# - RMSE: 140.67, - MAE: 104.75, - MAPE: 1.17,  - R2: 0.81,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 62 / AVG train loss : 2.348891158934504
# Test:
#  Avg loss: 5.596172,
#
# - RMSE: 142.17, - MAE: 107.38, - MAPE: 1.15,  - R2: 0.80,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 63 / AVG train loss : 2.3875910284171806
# Test:
#  Avg loss: 5.690059,
#
# - RMSE: 143.36, - MAE: 109.27, - MAPE: 1.13,  - R2: 0.80,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 64 / AVG train loss : 2.4151763467014713
# Test:
#  Avg loss: 5.730058,
#
# - RMSE: 143.86, - MAE: 110.19, - MAPE: 1.11,  - R2: 0.80,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 65 / AVG train loss : 2.42405931122449
# Test:
#  Avg loss: 5.701629,
#
# - RMSE: 143.51, - MAE: 110.10, - MAPE: 1.09,  - R2: 0.80,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 66 / AVG train loss : 2.410603605541054
# Test:
#  Avg loss: 5.607287,
#
# - RMSE: 142.31, - MAE: 109.10, - MAPE: 1.08,  - R2: 0.80,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 67 / AVG train loss : 2.3742510085429522
# Test:
#  Avg loss: 5.462004,
#
# - RMSE: 140.46, - MAE: 107.31, - MAPE: 1.06,  - R2: 0.81,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 68 / AVG train loss : 2.320186802918842
# Test:
#  Avg loss: 5.281760,
#
# - RMSE: 138.12, - MAE: 104.93, - MAPE: 1.04,  - R2: 0.81,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 69 / AVG train loss : 2.254015447021832
# Test:
#  Avg loss: 5.081926,
#
# - RMSE: 135.48, - MAE: 102.22, - MAPE: 1.03,  - R2: 0.82,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 70 / AVG train loss : 2.1816050293663976
# Test:
#  Avg loss: 4.885466,
#
# - RMSE: 132.84, - MAE: 99.25, - MAPE: 1.01,  - R2: 0.83,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 71 / AVG train loss : 2.11039151489084
# Test:
#  Avg loss: 4.706560,
#
# - RMSE: 130.38, - MAE: 96.11, - MAPE: 1.00,  - R2: 0.83,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 72 / AVG train loss : 2.045012161841481
# Test:
#  Avg loss: 4.552951,
#
# - RMSE: 128.24, - MAE: 93.02, - MAPE: 0.98,  - R2: 0.84,  - RUL_metric: 0.87,
#
# ------------------------------------------------------------
# Epoch : 73 / AVG train loss : 1.987669820835311
# Test:
#  Avg loss: 4.426822,
#
# - RMSE: 126.45, - MAE: 90.16, - MAPE: 0.96,  - R2: 0.84,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------
# Epoch : 74 / AVG train loss : 1.9391776296274323
# Test:
#  Avg loss: 4.328216,
#
# - RMSE: 125.03, - MAE: 87.57, - MAPE: 0.94,  - R2: 0.85,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------
# Epoch : 75 / AVG train loss : 1.8998657747982914
# Test:
#  Avg loss: 4.255830,
#
# - RMSE: 123.98, - MAE: 85.48, - MAPE: 0.91,  - R2: 0.85,  - RUL_metric: 0.85,
#
# ------------------------------------------------------------
# Epoch : 76 / AVG train loss : 1.8698942513051733
# Test:
#  Avg loss: 4.207562,
#
# - RMSE: 123.28, - MAE: 84.15, - MAPE: 0.89,  - R2: 0.85,  - RUL_metric: 0.84,
#
# ------------------------------------------------------------
# Epoch : 77 / AVG train loss : 1.8489484456573326
# Test:
#  Avg loss: 4.180111,
#
# - RMSE: 122.88, - MAE: 83.49, - MAPE: 0.87,  - R2: 0.85,  - RUL_metric: 0.84,
#
# ------------------------------------------------------------
# Epoch : 78 / AVG train loss : 1.8359399101210252
# Test:
#  Avg loss: 4.169082,
#
# - RMSE: 122.71, - MAE: 83.18, - MAPE: 0.85,  - R2: 0.85,  - RUL_metric: 0.83,
#
# ------------------------------------------------------------
# Epoch : 79 / AVG train loss : 1.8290035818106312
# Test:
#  Avg loss: 4.169707,
#
# - RMSE: 122.72, - MAE: 83.08, - MAPE: 0.83,  - R2: 0.85,  - RUL_metric: 0.82,
#
# ------------------------------------------------------------
# Epoch : 80 / AVG train loss : 1.8259180707166587
# Test:
#  Avg loss: 4.176928,
#
# - RMSE: 122.83, - MAE: 83.13, - MAPE: 0.81,  - R2: 0.85,  - RUL_metric: 0.82,
#
# ------------------------------------------------------------
# Epoch : 81 / AVG train loss : 1.8244884981608922
# Test:
#  Avg loss: 4.186251,
#
# - RMSE: 122.97, - MAE: 83.24, - MAPE: 0.80,  - R2: 0.85,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 82 / AVG train loss : 1.8230099816089227
# Test:
#  Avg loss: 4.193762,
#
# - RMSE: 123.08, - MAE: 83.39, - MAPE: 0.78,  - R2: 0.85,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 83 / AVG train loss : 1.8203631125415283
# Test:
#  Avg loss: 4.196771,
#
# - RMSE: 123.12, - MAE: 83.51, - MAPE: 0.77,  - R2: 0.85,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 84 / AVG train loss : 1.8159181077954438
# Test:
#  Avg loss: 4.192915,
#
# - RMSE: 123.06, - MAE: 83.57, - MAPE: 0.76,  - R2: 0.85,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 85 / AVG train loss : 1.8091962802562886
# Test:
#  Avg loss: 4.180775,
#
# - RMSE: 122.89, - MAE: 83.53, - MAPE: 0.75,  - R2: 0.85,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 86 / AVG train loss : 1.7999460503678215
# Test:
#  Avg loss: 4.159732,
#
# - RMSE: 122.58, - MAE: 83.38, - MAPE: 0.74,  - R2: 0.85,  - RUL_metric: 0.80,
#
# ------------------------------------------------------------
# Epoch : 87 / AVG train loss : 1.7880289288680589
# Test:
#  Avg loss: 4.130339,
#
# - RMSE: 122.14, - MAE: 83.13, - MAPE: 0.74,  - R2: 0.85,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 88 / AVG train loss : 1.7736184444708116
# Test:
#  Avg loss: 4.094221,
#
# - RMSE: 121.61, - MAE: 82.80, - MAPE: 0.73,  - R2: 0.86,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 89 / AVG train loss : 1.7572218349549122
# Test:
#  Avg loss: 4.054257,
#
# - RMSE: 121.01, - MAE: 82.43, - MAPE: 0.72,  - R2: 0.86,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 90 / AVG train loss : 1.7396381481371619
# Test:
#  Avg loss: 4.013084,
#
# - RMSE: 120.40, - MAE: 82.04, - MAPE: 0.72,  - R2: 0.86,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 91 / AVG train loss : 1.7217678423113432
# Test:
#  Avg loss: 3.972582,
#
# - RMSE: 119.79, - MAE: 81.65, - MAPE: 0.72,  - R2: 0.86,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 92 / AVG train loss : 1.7044021787494068
# Test:
#  Avg loss: 3.934120,
#
# - RMSE: 119.21, - MAE: 81.31, - MAPE: 0.71,  - R2: 0.86,  - RUL_metric: 0.82,
#
# ------------------------------------------------------------
# Epoch : 93 / AVG train loss : 1.6880411648671096
# Test:
#  Avg loss: 3.899163,
#
# - RMSE: 118.68, - MAE: 81.01, - MAPE: 0.71,  - R2: 0.86,  - RUL_metric: 0.82,
#
# ------------------------------------------------------------
# Epoch : 94 / AVG train loss : 1.672969751127195
# Test:
#  Avg loss: 3.867590,
#
# - RMSE: 118.19, - MAE: 80.76, - MAPE: 0.71,  - R2: 0.86,  - RUL_metric: 0.82,
#
# ------------------------------------------------------------
# Epoch : 95 / AVG train loss : 1.6593679550308496
# Test:
#  Avg loss: 3.840042,
#
# - RMSE: 117.77, - MAE: 80.58, - MAPE: 0.71,  - R2: 0.86,  - RUL_metric: 0.83,
#
# ------------------------------------------------------------
# Epoch : 96 / AVG train loss : 1.6473310690555292
# Test:
#  Avg loss: 3.816229,
#
# - RMSE: 117.41, - MAE: 80.45, - MAPE: 0.71,  - R2: 0.87,  - RUL_metric: 0.83,
#
# ------------------------------------------------------------
# Epoch : 97 / AVG train loss : 1.6369656947081157
# Test:
#  Avg loss: 3.795672,
#
# - RMSE: 117.09, - MAE: 80.35, - MAPE: 0.71,  - R2: 0.87,  - RUL_metric: 0.83,
#
# ------------------------------------------------------------
# Epoch : 98 / AVG train loss : 1.6281976744186046
# Test:
#  Avg loss: 3.777386,
#
# - RMSE: 116.81, - MAE: 80.25, - MAPE: 0.70,  - R2: 0.87,  - RUL_metric: 0.84,
#
# ------------------------------------------------------------
# Epoch : 99 / AVG train loss : 1.6207387206336024
# Test:
#  Avg loss: 3.761027,
#
# - RMSE: 116.55, - MAE: 80.16, - MAPE: 0.70,  - R2: 0.87,  - RUL_metric: 0.84,
#
# ------------------------------------------------------------
# Epoch : 100 / AVG train loss : 1.6139727693402943
# Test:
#  Avg loss: 3.745965,
#
# - RMSE: 116.32, - MAE: 80.09, - MAPE: 0.70,  - R2: 0.87,  - RUL_metric: 0.84,
#
# ------------------------------------------------------------

# %%
# 함수로 만들어서 사용합시다.
def dl_history_plot(train_loss_list, test_loss_list):
    plt.figure(figsize=(10,6))
    plt.plot(train_loss_list, label='train_err', marker = '.')
    plt.plot(test_loss_list, label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()
    
dl_history_plot(train_loss_list, test_loss_list)

# %%
def visualization_result(y_val,pred, size=100):
  sns.lineplot(y_val[:size], label='valid train')
  sns.lineplot(pred.reshape(pred.shape[0],)[:size], label='pred')
  plt.legend(loc='upper right')
  plt.show()

# %%
pred = best_model(X_test_s)

# %%
pred = pred.detach().cpu().numpy()
y_test_s = y_test_s.detach().cpu().numpy()

# %%
from sklearn.metrics import * 

def RUL_metric(y_valid, y_pred, threshold=10):

    error = y_valid.reshape(-1) - y_pred.reshape(-1)
    per = np.where(error<=threshold, 1, 0)
    
    return sum(per) / len(per)

print(f'RMSE : {mean_squared_error(y_test_s, pred, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_test_s, pred)}')
print(f'MAPE : {mean_absolute_percentage_error(y_test_s, pred)}')
print(f'R2 : {r2_score(y_test_s, pred)}')
print(f'RUL_metric : {RUL_metric(y_test_s, pred, threshold=100)}')
# Out:
# RMSE : 117.77008056640625
# MAE  : 82.8531723022461
# MAPE : 0.5314784049987793
# R2 : 0.8648987515469544
# RUL_metric : 0.8172757475083057

# %%
def visualization_result(y_val,pred, size=100):
  sns.lineplot(y_val.reshape(y_val.shape[0],)[:size], label='valid train')
  sns.lineplot(pred.reshape(pred.shape[0],)[:size], label='pred')
  plt.legend(loc='upper right')
  plt.show()

# %%
visualization_result(y_test_s,pred, size=100)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn 
import torch.optim as optim

from sklearn.model_selection import train_test_split
from sklearn.metrics import * 
from tqdm import tqdm 

import warnings
warnings.filterwarnings("ignore")

# %%
def RUL_metric(y_valid, y_pred, threshold=10):

    error = y_valid.reshape(-1) - y_pred.reshape(-1)
    per = np.where(error<=threshold, 1, 0)
    
    return sum(per) / len(per)

# %%
# sns.set()

# %%
path = "data/Battery_RUL.csv"

# %%
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    Cycle_Index  Discharge Time (s)  Decrement 3.6-3.4V (s)  \
# 0          1.0             2595.30             1151.488500
# 1          2.0             7408.64             1172.512500
# 2          3.0             7393.76             1112.992000
# 3          4.0             7385.50             1080.320667
# 4          6.0            65022.75            29813.487000
#
#    Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)  \
# 0                      3.670                    3.211           5460.001
# 1                      4.246                    3.220           5508.992
# 2                      4.249                    3.224           5508.993
# 3                      4.250                    3.225           5502.016
# 4                      4.290                    3.398           5480.992
#
#    Time constant current (s)  Charging time (s)   RUL
# 0                    6755.01           10777.82  1112
# 1                    6762.02           10500.35  1111
# 2                    6762.02           10420.38  1110
# 3                    6762.02           10322.81  1109
# 4                   53213.54           56699.65  1107

# %%
data.shape
# Out:
# (15064, 9)

# %%
# 다음 컬럼들은 RUL에 관계가 없기 때문에 제거한다.
data=data.drop(['Cycle_Index','Discharge Time (s)', 'Decrement 3.6-3.4V (s)', 'Time constant current (s)','Charging time (s)'],axis=1)

# %%
data.head()
# Out:
#    Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)   RUL
# 0                      3.670                    3.211           5460.001  1112
# 1                      4.246                    3.220           5508.992  1111
# 2                      4.249                    3.224           5508.993  1110
# 3                      4.250                    3.225           5502.016  1109
# 4                      4.290                    3.398           5480.992  1107

# %% [markdown]
# ## Modeling and Predections

# %%
data = data[data['RUL']!=0]

X = data.drop(['RUL'], axis=1)
y = data['RUL']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=2023, shuffle =True)
X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size=0.2, random_state=2023, shuffle =True)

# %%
class Pipeline:
    def __init__(self, scalar):
        self.scalar = scalar
    
    def fit(self, X, y):
        X = self.scalar.fit_transform(X)
        return X, y.to_numpy(dtype=np.float32)
    
    def transform(self, X, y):
        X = self.scalar.transform(X)
        return X, y.to_numpy(dtype=np.float32)

# %%
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler
# 실험상 RobustScaler 또는 StandardScaler가 성능이 가장 낮다 
robust = RobustScaler()
pipeline = Pipeline(robust)

# %%
X_train_s, y_train_s = pipeline.fit(X_train, y_train)

X_val_s, y_val_s = pipeline.transform(X_val, y_val)
X_test_s, y_test_s = pipeline.transform(X_test, y_test)

# %%
X_train_s = torch.FloatTensor(X_train_s)
y_train_s = torch.FloatTensor(y_train_s).unsqueeze(-1)

X_val_s = torch.FloatTensor(X_val_s)
y_val_s = torch.FloatTensor(y_val_s).unsqueeze(-1)

X_test_s = torch.FloatTensor(X_test_s)
y_test_s = torch.FloatTensor(y_test_s).unsqueeze(-1)

# %%
X_train_s.shape, y_train_s.shape, X_val_s.shape, y_val_s.shape, X_test_s.shape, y_test_s.shape
# Out:
# (torch.Size([10535, 3]),
#  torch.Size([10535, 1]),
#  torch.Size([3612, 3]),
#  torch.Size([3612, 1]),
#  torch.Size([903, 3]),
#  torch.Size([903, 1]))

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.l1 = nn.Linear(input_size, hidden_size)
        self.l2 = nn.Linear(hidden_size, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        return out

# %%
input_size =  X_train_s.shape[1] #num of columns
hidden_size = 16
num_classes = 1

model = NeuralNet(input_size, hidden_size, num_classes)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.1, weight_decay=1e-5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min')

# %%
train_loss_list = []
test_loss_list = []
min_diff_dict = {}

targets_list = []
pred_list = []
epoch_list = []
MAE_list= []
RUL_score_list = []
best_MAE = np.inf
best_model = 0
# for epoch in tqdm(range(1, 101)):
for epoch in range(1, 101):
    size = len(X_train_s)
    optimizer.zero_grad()
    outputs = model(X_train_s)
    loss = criterion(outputs, y_train_s)
    loss.backward()
    optimizer.step()
    print(f'Epoch : {epoch} / AVG train loss : {loss.item()/size}')
    train_loss_list.append(loss.item()/size)
    
    with torch.no_grad():
        size = len(X_val_s)
        pred = model(X_val_s)
        test_loss = criterion(pred, y_val_s)
        
        test_loss_list.append(test_loss.item()/size)
        pred_np = pred.squeeze().tolist()
        target_np = y_val_s.squeeze().tolist()
        
        try:
            for i,j in zip(pred_np,target_np):
                pred_list.append(i)
                targets_list.append(j)
        except:
            pass
        
        pred = pred.detach().cpu().numpy()
        y = y_val_s.detach().cpu().numpy()
    
        RMSE = mean_squared_error(y, pred, squared=False)
        MAE = mean_absolute_error(y, pred)
        MAPE = mean_absolute_percentage_error(y, pred)
        R2 = r2_score(y, pred)
        RUL_score = RUL_metric(y, pred, threshold=100)
        msg = f"Test: \n Avg loss: {test_loss.item()/size:>8f}, \n"
        print(msg) 
        msg = f"- RMSE: {(RMSE):>0.2f}, - MAE: {(MAE):>0.2f}, - MAPE: {(MAPE):>0.2f},  - R2: {(R2):>0.2f},  - RUL_metric: {(RUL_score):>0.2f}, \n"
        print(msg)
        print('---'*20)
        
        scheduler.step(test_loss)

    epoch_list.append(epoch)
    MAE_list.append(MAE)
    RUL_score_list.append(RUL_score*100)
    
    mean_MAE = np.mean(MAE_list)
    if mean_MAE < best_MAE:
        best_MAE = mean_MAE
        best_model = model
    
plt.figure(figsize=(10,8))
plt.subplot(3,1,1)
plt.scatter(targets_list, pred_list)
plt.xlabel('Target', fontsize=10)
plt.ylabel('Prediction', fontsize=10)
plt.ylim(0, 1300)
plt.title(f"Epoch {epoch+1}", fontsize=13)

plt.subplot(3,1,2)
# plt.scatter(epoch_list, MAE_list)
plt.plot(MAE_list, label='RUL_score', marker = '.')
plt.ylim(0, 1000)
plt.xlabel('Epoch')
plt.ylabel('Target-Pred MAE')

# PLOT Difference
plt.subplot(3,1,3)
# plt.scatter(epoch_list, RUL_score_list)
plt.plot(RUL_score_list, label='RUL_score', marker = '.')
plt.ylim(0, 100)
plt.xlabel('Epoch')
plt.ylabel('Target-Pred RUL_score (%)')
# plt.scatter(epoch, test_loss)
plt.tight_layout()

plt.savefig(f'./result/training_{epoch}.png')
# Out:
# Epoch : 1 / AVG train loss : 39.022858329378266
# Test:
#  Avg loss: 113.325339,
#
# - RMSE: 639.79, - MAE: 554.16, - MAPE: 1.00,  - R2: -3.00,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 2 / AVG train loss : 38.94962921214998
# Test:
#  Avg loss: 113.110292,
#
# - RMSE: 639.18, - MAE: 553.53, - MAPE: 0.99,  - R2: -2.99,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 3 / AVG train loss : 38.869912790697676
# Test:
#  Avg loss: 112.846899,
#
# - RMSE: 638.44, - MAE: 552.75, - MAPE: 0.99,  - R2: -2.99,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 4 / AVG train loss : 38.772855363075465
# Test:
#  Avg loss: 112.512606,
#
# - RMSE: 637.49, - MAE: 551.75, - MAPE: 0.99,  - R2: -2.97,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 5 / AVG train loss : 38.65020467489321
# Test:
#  Avg loss: 112.097851,
#
# - RMSE: 636.32, - MAE: 550.51, - MAPE: 0.98,  - R2: -2.96,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 6 / AVG train loss : 38.49867406264831
# Test:
#  Avg loss: 111.593811,
#
# - RMSE: 634.88, - MAE: 548.99, - MAPE: 0.98,  - R2: -2.94,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 7 / AVG train loss : 38.31543663977219
# Test:
#  Avg loss: 110.994299,
#
# - RMSE: 633.18, - MAE: 547.16, - MAPE: 0.97,  - R2: -2.92,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 8 / AVG train loss : 38.0984782866635
# Test:
#  Avg loss: 110.295352,
#
# - RMSE: 631.18, - MAE: 545.05, - MAPE: 0.97,  - R2: -2.90,  - RUL_metric: 0.10,
#
# ------------------------------------------------------------
# Epoch : 9 / AVG train loss : 37.846823089701
# Test:
#  Avg loss: 109.484834,
#
# - RMSE: 628.86, - MAE: 542.62, - MAPE: 0.97,  - R2: -2.87,  - RUL_metric: 0.10,
#
# ------------------------------------------------------------
# Epoch : 10 / AVG train loss : 37.556896654010444
# Test:
#  Avg loss: 108.548701,
#
# - RMSE: 626.16, - MAE: 539.80, - MAPE: 0.97,  - R2: -2.83,  - RUL_metric: 0.10,
#
# ------------------------------------------------------------
# Epoch : 11 / AVG train loss : 37.224516492643566
# Test:
#  Avg loss: 107.493529,
#
# - RMSE: 623.11, - MAE: 536.59, - MAPE: 0.97,  - R2: -2.80,  - RUL_metric: 0.11,
#
# ------------------------------------------------------------
# Epoch : 12 / AVG train loss : 36.85259551495017
# Test:
#  Avg loss: 106.321740,
#
# - RMSE: 619.70, - MAE: 533.02, - MAPE: 0.98,  - R2: -2.75,  - RUL_metric: 0.11,
#
# ------------------------------------------------------------
# Epoch : 13 / AVG train loss : 36.443696606549594
# Test:
#  Avg loss: 105.033231,
#
# - RMSE: 615.94, - MAE: 529.10, - MAPE: 0.98,  - R2: -2.71,  - RUL_metric: 0.12,
#
# ------------------------------------------------------------
# Epoch : 14 / AVG train loss : 35.99928512102515
# Test:
#  Avg loss: 103.628227,
#
# - RMSE: 611.80, - MAE: 524.92, - MAPE: 0.99,  - R2: -2.66,  - RUL_metric: 0.12,
#
# ------------------------------------------------------------
# Epoch : 15 / AVG train loss : 35.52133958234457
# Test:
#  Avg loss: 102.110716,
#
# - RMSE: 607.31, - MAE: 520.42, - MAPE: 1.00,  - R2: -2.61,  - RUL_metric: 0.12,
#
# ------------------------------------------------------------
# Epoch : 16 / AVG train loss : 35.01317631703844
# Test:
#  Avg loss: 100.489774,
#
# - RMSE: 602.47, - MAE: 515.65, - MAPE: 1.02,  - R2: -2.55,  - RUL_metric: 0.13,
#
# ------------------------------------------------------------
# Epoch : 17 / AVG train loss : 34.479912197437116
# Test:
#  Avg loss: 98.775834,
#
# - RMSE: 597.31, - MAE: 510.61, - MAPE: 1.04,  - R2: -2.49,  - RUL_metric: 0.13,
#
# ------------------------------------------------------------
# Epoch : 18 / AVG train loss : 33.92735524442335
# Test:
#  Avg loss: 96.981200,
#
# - RMSE: 591.86, - MAE: 505.38, - MAPE: 1.06,  - R2: -2.42,  - RUL_metric: 0.14,
#
# ------------------------------------------------------------
# Epoch : 19 / AVG train loss : 33.36185334598956
# Test:
#  Avg loss: 95.120146,
#
# - RMSE: 586.15, - MAE: 499.89, - MAPE: 1.08,  - R2: -2.36,  - RUL_metric: 0.15,
#
# ------------------------------------------------------------
# Epoch : 20 / AVG train loss : 32.789466658756524
# Test:
#  Avg loss: 93.207036,
#
# - RMSE: 580.23, - MAE: 494.29, - MAPE: 1.11,  - R2: -2.29,  - RUL_metric: 0.15,
#
# ------------------------------------------------------------
# Epoch : 21 / AVG train loss : 32.21449632178453
# Test:
#  Avg loss: 91.253504,
#
# - RMSE: 574.11, - MAE: 488.71, - MAPE: 1.14,  - R2: -2.22,  - RUL_metric: 0.16,
#
# ------------------------------------------------------------
# Epoch : 22 / AVG train loss : 31.637378381585194
# Test:
#  Avg loss: 89.264154,
#
# - RMSE: 567.82, - MAE: 482.82, - MAPE: 1.18,  - R2: -2.15,  - RUL_metric: 0.17,
#
# ------------------------------------------------------------
# Epoch : 23 / AVG train loss : 31.052883246321784
# Test:
#  Avg loss: 87.234756,
#
# - RMSE: 561.33, - MAE: 476.67, - MAPE: 1.22,  - R2: -2.08,  - RUL_metric: 0.18,
#
# ------------------------------------------------------------
# Epoch : 24 / AVG train loss : 30.451542477456098
# Test:
#  Avg loss: 85.156734,
#
# - RMSE: 554.60, - MAE: 470.28, - MAPE: 1.26,  - R2: -2.01,  - RUL_metric: 0.19,
#
# ------------------------------------------------------------
# Epoch : 25 / AVG train loss : 29.8234011627907
# Test:
#  Avg loss: 83.021465,
#
# - RMSE: 547.61, - MAE: 463.69, - MAPE: 1.31,  - R2: -1.93,  - RUL_metric: 0.20,
#
# ------------------------------------------------------------
# Epoch : 26 / AVG train loss : 29.160758780256288
# Test:
#  Avg loss: 80.822406,
#
# - RMSE: 540.31, - MAE: 456.96, - MAPE: 1.35,  - R2: -1.85,  - RUL_metric: 0.20,
#
# ------------------------------------------------------------
# Epoch : 27 / AVG train loss : 28.458839582344567
# Test:
#  Avg loss: 78.555042,
#
# - RMSE: 532.67, - MAE: 450.04, - MAPE: 1.40,  - R2: -1.77,  - RUL_metric: 0.21,
#
# ------------------------------------------------------------
# Epoch : 28 / AVG train loss : 27.715226032273375
# Test:
#  Avg loss: 76.215904,
#
# - RMSE: 524.68, - MAE: 442.94, - MAPE: 1.45,  - R2: -1.69,  - RUL_metric: 0.22,
#
# ------------------------------------------------------------
# Epoch : 29 / AVG train loss : 26.92892441860465
# Test:
#  Avg loss: 73.802153,
#
# - RMSE: 516.31, - MAE: 435.64, - MAPE: 1.51,  - R2: -1.61,  - RUL_metric: 0.22,
#
# ------------------------------------------------------------
# Epoch : 30 / AVG train loss : 26.099753796867585
# Test:
#  Avg loss: 71.307421,
#
# - RMSE: 507.51, - MAE: 428.13, - MAPE: 1.55,  - R2: -1.52,  - RUL_metric: 0.23,
#
# ------------------------------------------------------------
# Epoch : 31 / AVG train loss : 25.226892501186523
# Test:
#  Avg loss: 68.716488,
#
# - RMSE: 498.20, - MAE: 420.34, - MAPE: 1.60,  - R2: -1.43,  - RUL_metric: 0.24,
#
# ------------------------------------------------------------
# Epoch : 32 / AVG train loss : 24.30719476744186
# Test:
#  Avg loss: 66.031830,
#
# - RMSE: 488.37, - MAE: 412.19, - MAPE: 1.64,  - R2: -1.33,  - RUL_metric: 0.24,
#
# ------------------------------------------------------------
# Epoch : 33 / AVG train loss : 23.342931300427146
# Test:
#  Avg loss: 63.262121,
#
# - RMSE: 478.02, - MAE: 403.70, - MAPE: 1.68,  - R2: -1.23,  - RUL_metric: 0.25,
#
# ------------------------------------------------------------
# Epoch : 34 / AVG train loss : 22.33919820835311
# Test:
#  Avg loss: 60.427382,
#
# - RMSE: 467.19, - MAE: 394.86, - MAPE: 1.72,  - R2: -1.13,  - RUL_metric: 0.25,
#
# ------------------------------------------------------------
# Epoch : 35 / AVG train loss : 21.311378737541528
# Test:
#  Avg loss: 57.527244,
#
# - RMSE: 455.84, - MAE: 385.60, - MAPE: 1.75,  - R2: -1.03,  - RUL_metric: 0.26,
#
# ------------------------------------------------------------
# Epoch : 36 / AVG train loss : 20.251008542952064
# Test:
#  Avg loss: 54.565433,
#
# - RMSE: 443.95, - MAE: 375.88, - MAPE: 1.78,  - R2: -0.93,  - RUL_metric: 0.27,
#
# ------------------------------------------------------------
# Epoch : 37 / AVG train loss : 19.171179401993356
# Test:
#  Avg loss: 51.548350,
#
# - RMSE: 431.50, - MAE: 365.67, - MAPE: 1.80,  - R2: -0.82,  - RUL_metric: 0.28,
#
# ------------------------------------------------------------
# Epoch : 38 / AVG train loss : 18.075557664926436
# Test:
#  Avg loss: 48.486278,
#
# - RMSE: 418.49, - MAE: 354.89, - MAPE: 1.81,  - R2: -0.71,  - RUL_metric: 0.29,
#
# ------------------------------------------------------------
# Epoch : 39 / AVG train loss : 16.974781976744186
# Test:
#  Avg loss: 45.383608,
#
# - RMSE: 404.88, - MAE: 343.50, - MAPE: 1.82,  - R2: -0.60,  - RUL_metric: 0.29,
#
# ------------------------------------------------------------
# Epoch : 40 / AVG train loss : 15.868171570953963
# Test:
#  Avg loss: 42.235629,
#
# - RMSE: 390.58, - MAE: 331.44, - MAPE: 1.83,  - R2: -0.49,  - RUL_metric: 0.30,
#
# ------------------------------------------------------------
# Epoch : 41 / AVG train loss : 14.751601803512102
# Test:
#  Avg loss: 39.046378,
#
# - RMSE: 375.55, - MAE: 318.67, - MAPE: 1.83,  - R2: -0.38,  - RUL_metric: 0.31,
#
# ------------------------------------------------------------
# Epoch : 42 / AVG train loss : 13.626457937826293
# Test:
#  Avg loss: 35.812016,
#
# - RMSE: 359.66, - MAE: 305.12, - MAPE: 1.82,  - R2: -0.26,  - RUL_metric: 0.32,
#
# ------------------------------------------------------------
# Epoch : 43 / AVG train loss : 12.493315436639772
# Test:
#  Avg loss: 32.543814,
#
# - RMSE: 342.85, - MAE: 290.71, - MAPE: 1.80,  - R2: -0.15,  - RUL_metric: 0.33,
#
# ------------------------------------------------------------
# Epoch : 44 / AVG train loss : 11.35718883483626
# Test:
#  Avg loss: 29.260105,
#
# - RMSE: 325.10, - MAE: 275.46, - MAPE: 1.78,  - R2: -0.03,  - RUL_metric: 0.34,
#
# ------------------------------------------------------------
# Epoch : 45 / AVG train loss : 10.22562663146654
# Test:
#  Avg loss: 25.982102,
#
# - RMSE: 306.35, - MAE: 259.40, - MAPE: 1.76,  - R2: 0.08,  - RUL_metric: 0.36,
#
# ------------------------------------------------------------
# Epoch : 46 / AVG train loss : 9.105981549596583
# Test:
#  Avg loss: 22.767319,
#
# - RMSE: 286.77, - MAE: 242.72, - MAPE: 1.73,  - R2: 0.20,  - RUL_metric: 0.37,
#
# ------------------------------------------------------------
# Epoch : 47 / AVG train loss : 8.014307961556716
# Test:
#  Avg loss: 19.665170,
#
# - RMSE: 266.52, - MAE: 225.36, - MAPE: 1.69,  - R2: 0.31,  - RUL_metric: 0.39,
#
# ------------------------------------------------------------
# Epoch : 48 / AVG train loss : 6.96468913146654
# Test:
#  Avg loss: 16.730707,
#
# - RMSE: 245.83, - MAE: 207.33, - MAPE: 1.66,  - R2: 0.41,  - RUL_metric: 0.41,
#
# ------------------------------------------------------------
# Epoch : 49 / AVG train loss : 5.974620313241576
# Test:
#  Avg loss: 14.020824,
#
# - RMSE: 225.04, - MAE: 188.76, - MAPE: 1.61,  - R2: 0.50,  - RUL_metric: 0.43,
#
# ------------------------------------------------------------
# Epoch : 50 / AVG train loss : 5.061746929876602
# Test:
#  Avg loss: 11.642057,
#
# - RMSE: 205.06, - MAE: 170.01, - MAPE: 1.57,  - R2: 0.59,  - RUL_metric: 0.47,
#
# ------------------------------------------------------------
# Epoch : 51 / AVG train loss : 4.261158860346464
# Test:
#  Avg loss: 9.675363,
#
# - RMSE: 186.94, - MAE: 151.51, - MAPE: 1.52,  - R2: 0.66,  - RUL_metric: 0.52,
#
# ------------------------------------------------------------
# Epoch : 52 / AVG train loss : 3.603168752966303
# Test:
#  Avg loss: 8.092450,
#
# - RMSE: 170.97, - MAE: 133.75, - MAPE: 1.48,  - R2: 0.71,  - RUL_metric: 0.58,
#
# ------------------------------------------------------------
# Epoch : 53 / AVG train loss : 3.0784740967607975
# Test:
#  Avg loss: 6.878832,
#
# - RMSE: 157.63, - MAE: 117.36, - MAPE: 1.44,  - R2: 0.76,  - RUL_metric: 0.67,
#
# ------------------------------------------------------------
# Epoch : 54 / AVG train loss : 2.678363045799715
# Test:
#  Avg loss: 6.108793,
#
# - RMSE: 148.54, - MAE: 103.55, - MAPE: 1.40,  - R2: 0.78,  - RUL_metric: 0.79,
#
# ------------------------------------------------------------
# Epoch : 55 / AVG train loss : 2.426127009670147
# Test:
#  Avg loss: 5.613564,
#
# - RMSE: 142.39, - MAE: 94.43, - MAPE: 1.37,  - R2: 0.80,  - RUL_metric: 0.83,
#
# ------------------------------------------------------------
# Epoch : 56 / AVG train loss : 2.269644154900332
# Test:
#  Avg loss: 5.392887,
#
# - RMSE: 139.57, - MAE: 91.10, - MAPE: 1.35,  - R2: 0.81,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------
# Epoch : 57 / AVG train loss : 2.203280916290935
# Test:
#  Avg loss: 5.319384,
#
# - RMSE: 138.61, - MAE: 94.12, - MAPE: 1.34,  - R2: 0.81,  - RUL_metric: 0.87,
#
# ------------------------------------------------------------
# Epoch : 58 / AVG train loss : 2.1865122211675367
# Test:
#  Avg loss: 5.319292,
#
# - RMSE: 138.61, - MAE: 99.18, - MAPE: 1.34,  - R2: 0.81,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 59 / AVG train loss : 2.195124510560038
# Test:
#  Avg loss: 5.399350,
#
# - RMSE: 139.65, - MAE: 104.17, - MAPE: 1.34,  - R2: 0.81,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 60 / AVG train loss : 2.235657369779307
# Test:
#  Avg loss: 5.536027,
#
# - RMSE: 141.41, - MAE: 108.50, - MAPE: 1.33,  - R2: 0.80,  - RUL_metric: 0.91,
#
# ------------------------------------------------------------
# Epoch : 61 / AVG train loss : 2.3011794761509257
# Test:
#  Avg loss: 5.701865,
#
# - RMSE: 143.51, - MAE: 111.99, - MAPE: 1.33,  - R2: 0.80,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 62 / AVG train loss : 2.3784086527052684
# Test:
#  Avg loss: 5.848278,
#
# - RMSE: 145.34, - MAE: 114.48, - MAPE: 1.32,  - R2: 0.79,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 63 / AVG train loss : 2.447802155018984
# Test:
#  Avg loss: 5.945330,
#
# - RMSE: 146.54, - MAE: 115.90, - MAPE: 1.30,  - R2: 0.79,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 64 / AVG train loss : 2.4959424685571903
# Test:
#  Avg loss: 5.973052,
#
# - RMSE: 146.88, - MAE: 116.23, - MAPE: 1.28,  - R2: 0.79,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 65 / AVG train loss : 2.5119453013763646
# Test:
#  Avg loss: 5.921971,
#
# - RMSE: 146.25, - MAE: 115.48, - MAPE: 1.26,  - R2: 0.79,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 66 / AVG train loss : 2.4936491457047936
# Test:
#  Avg loss: 5.802219,
#
# - RMSE: 144.77, - MAE: 113.81, - MAPE: 1.23,  - R2: 0.80,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 67 / AVG train loss : 2.4467391062529664
# Test:
#  Avg loss: 5.632588,
#
# - RMSE: 142.64, - MAE: 111.39, - MAPE: 1.20,  - R2: 0.80,  - RUL_metric: 0.91,
#
# ------------------------------------------------------------
# Epoch : 68 / AVG train loss : 2.3801978894755575
# Test:
#  Avg loss: 5.431146,
#
# - RMSE: 140.06, - MAE: 108.39, - MAPE: 1.16,  - R2: 0.81,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 69 / AVG train loss : 2.304217526400095
# Test:
#  Avg loss: 5.408753,
#
# - RMSE: 139.77, - MAE: 108.04, - MAPE: 1.16,  - R2: 0.81,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 70 / AVG train loss : 2.295987148493118
# Test:
#  Avg loss: 5.383686,
#
# - RMSE: 139.45, - MAE: 107.66, - MAPE: 1.16,  - R2: 0.81,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 71 / AVG train loss : 2.2867682501779782
# Test:
#  Avg loss: 5.356375,
#
# - RMSE: 139.09, - MAE: 107.23, - MAPE: 1.15,  - R2: 0.81,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 72 / AVG train loss : 2.276746596167537
# Test:
#  Avg loss: 5.327218,
#
# - RMSE: 138.72, - MAE: 106.78, - MAPE: 1.15,  - R2: 0.81,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 73 / AVG train loss : 2.2660745802681537
# Test:
#  Avg loss: 5.296558,
#
# - RMSE: 138.32, - MAE: 106.30, - MAPE: 1.15,  - R2: 0.81,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 74 / AVG train loss : 2.254887540045088
# Test:
#  Avg loss: 5.264815,
#
# - RMSE: 137.90, - MAE: 105.80, - MAPE: 1.14,  - R2: 0.81,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 75 / AVG train loss : 2.2433052399738966
# Test:
#  Avg loss: 5.232275,
#
# - RMSE: 137.47, - MAE: 105.28, - MAPE: 1.14,  - R2: 0.82,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 76 / AVG train loss : 2.2314391018035122
# Test:
#  Avg loss: 5.199180,
#
# - RMSE: 137.04, - MAE: 104.75, - MAPE: 1.14,  - R2: 0.82,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 77 / AVG train loss : 2.2193834910417656
# Test:
#  Avg loss: 5.165793,
#
# - RMSE: 136.60, - MAE: 104.22, - MAPE: 1.14,  - R2: 0.82,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 78 / AVG train loss : 2.2072251720455625
# Test:
#  Avg loss: 5.132314,
#
# - RMSE: 136.15, - MAE: 103.67, - MAPE: 1.13,  - R2: 0.82,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 79 / AVG train loss : 2.1950383023849076
# Test:
#  Avg loss: 5.098906,
#
# - RMSE: 135.71, - MAE: 103.12, - MAPE: 1.13,  - R2: 0.82,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 80 / AVG train loss : 2.182895927266255
# Test:
#  Avg loss: 5.065730,
#
# - RMSE: 135.27, - MAE: 102.56, - MAPE: 1.13,  - R2: 0.82,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 81 / AVG train loss : 2.1708518109278594
# Test:
#  Avg loss: 5.032931,
#
# - RMSE: 134.83, - MAE: 102.00, - MAPE: 1.12,  - R2: 0.82,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 82 / AVG train loss : 2.158951374881348
# Test:
#  Avg loss: 5.000636,
#
# - RMSE: 134.40, - MAE: 101.44, - MAPE: 1.12,  - R2: 0.82,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 83 / AVG train loss : 2.147231883305648
# Test:
#  Avg loss: 4.968941,
#
# - RMSE: 133.97, - MAE: 100.88, - MAPE: 1.12,  - R2: 0.82,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 84 / AVG train loss : 2.1357307857736116
# Test:
#  Avg loss: 4.937961,
#
# - RMSE: 133.55, - MAE: 100.31, - MAPE: 1.11,  - R2: 0.83,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 85 / AVG train loss : 2.124484419494542
# Test:
#  Avg loss: 4.907772,
#
# - RMSE: 133.14, - MAE: 99.75, - MAPE: 1.11,  - R2: 0.83,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 86 / AVG train loss : 2.11351317780019
# Test:
#  Avg loss: 4.878412,
#
# - RMSE: 132.74, - MAE: 99.19, - MAPE: 1.11,  - R2: 0.83,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 87 / AVG train loss : 2.102831706810631
# Test:
#  Avg loss: 4.849931,
#
# - RMSE: 132.36, - MAE: 98.64, - MAPE: 1.11,  - R2: 0.83,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 88 / AVG train loss : 2.0924594728879926
# Test:
#  Avg loss: 4.822362,
#
# - RMSE: 131.98, - MAE: 98.09, - MAPE: 1.10,  - R2: 0.83,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 89 / AVG train loss : 2.082407785061699
# Test:
#  Avg loss: 4.795750,
#
# - RMSE: 131.61, - MAE: 97.55, - MAPE: 1.10,  - R2: 0.83,  - RUL_metric: 0.87,
#
# ------------------------------------------------------------
# Epoch : 90 / AVG train loss : 2.072684986058377
# Test:
#  Avg loss: 4.770103,
#
# - RMSE: 131.26, - MAE: 97.01, - MAPE: 1.10,  - R2: 0.83,  - RUL_metric: 0.87,
#
# ------------------------------------------------------------
# Epoch : 91 / AVG train loss : 2.063296081514001
# Test:
#  Avg loss: 4.745441,
#
# - RMSE: 130.92, - MAE: 96.48, - MAPE: 1.10,  - R2: 0.83,  - RUL_metric: 0.87,
#
# ------------------------------------------------------------
# Epoch : 92 / AVG train loss : 2.0542444085192217
# Test:
#  Avg loss: 4.721767,
#
# - RMSE: 130.59, - MAE: 95.96, - MAPE: 1.09,  - R2: 0.83,  - RUL_metric: 0.87,
#
# ------------------------------------------------------------
# Epoch : 93 / AVG train loss : 2.045529967074039
# Test:
#  Avg loss: 4.699079,
#
# - RMSE: 130.28, - MAE: 95.45, - MAPE: 1.09,  - R2: 0.83,  - RUL_metric: 0.87,
#
# ------------------------------------------------------------
# Epoch : 94 / AVG train loss : 2.0371510886331277
# Test:
#  Avg loss: 4.677368,
#
# - RMSE: 129.98, - MAE: 94.96, - MAPE: 1.09,  - R2: 0.83,  - RUL_metric: 0.87,
#
# ------------------------------------------------------------
# Epoch : 95 / AVG train loss : 2.029105919257238
# Test:
#  Avg loss: 4.656625,
#
# - RMSE: 129.69, - MAE: 94.48, - MAPE: 1.09,  - R2: 0.84,  - RUL_metric: 0.87,
#
# ------------------------------------------------------------
# Epoch : 96 / AVG train loss : 2.0213939027645944
# Test:
#  Avg loss: 4.636836,
#
# - RMSE: 129.42, - MAE: 94.01, - MAPE: 1.09,  - R2: 0.84,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------
# Epoch : 97 / AVG train loss : 2.0140076233981965
# Test:
#  Avg loss: 4.617981,
#
# - RMSE: 129.15, - MAE: 93.55, - MAPE: 1.08,  - R2: 0.84,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------
# Epoch : 98 / AVG train loss : 2.006938182249644
# Test:
#  Avg loss: 4.600037,
#
# - RMSE: 128.90, - MAE: 93.11, - MAPE: 1.08,  - R2: 0.84,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------
# Epoch : 99 / AVG train loss : 2.0001777927740862
# Test:
#  Avg loss: 4.582980,
#
# - RMSE: 128.66, - MAE: 92.68, - MAPE: 1.08,  - R2: 0.84,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------
# Epoch : 100 / AVG train loss : 1.9937223763051732
# Test:
#  Avg loss: 4.566776,
#
# - RMSE: 128.43, - MAE: 92.27, - MAPE: 1.08,  - R2: 0.84,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------

# %%
# 함수로 만들어서 사용합시다.
def dl_history_plot(train_loss_list, test_loss_list):
    plt.figure(figsize=(10,6))
    plt.plot(train_loss_list, label='train_err', marker = '.')
    plt.plot(test_loss_list, label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()
    
dl_history_plot(train_loss_list, test_loss_list)

# %%
def visualization_result(y_val,pred, size=100):
  sns.lineplot(y_val[:size], label='valid train')
  sns.lineplot(pred.reshape(pred.shape[0],)[:size], label='pred')
  plt.legend(loc='upper right')
  plt.show()

# %%
pred = best_model(X_test_s)

# %%
pred = pred.detach().cpu().numpy()
X_test_s = y_test_s.detach().cpu().numpy()

# %%
from sklearn.metrics import * 

def RUL_metric(y_valid, y_pred, threshold=10):

    error = y_valid.reshape(-1) - y_pred.reshape(-1)
    per = np.where(error<=threshold, 1, 0)
    
    return sum(per) / len(per)

print(f'RMSE : {mean_squared_error(y_test_s, pred, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_test_s, pred)}')
print(f'MAPE : {mean_absolute_percentage_error(y_test_s, pred)}')
print(f'R2 : {r2_score(y_test_s, pred)}')
print(f'RUL_metric : {RUL_metric(y_test_s, pred, threshold=100)}')
# Out:
# RMSE : 135.5886688232422
# MAE  : 97.48968505859375
# MAPE : 0.8379703760147095
# R2 : 0.820924484726845
# RUL_metric : 0.8272425249169435

# %%
def visualization_result(y_val,pred, size=100):
  sns.lineplot(y_val[:size], label='valid train')
  sns.lineplot(pred.reshape(pred.shape[0],)[:size], label='pred')
  plt.legend(loc='upper right')
  plt.show()

# %%
visualization_result(y_test_s,pred, size=100)
# Out:
# c:\Users\kim_h\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kim_h\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kim_h\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\kim_h\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

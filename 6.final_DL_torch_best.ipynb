# %%
import random
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn 
import torch.optim as optim

from sklearn.model_selection import train_test_split
from sklearn.metrics import * 
from tqdm import tqdm 

import warnings
warnings.filterwarnings("ignore")

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42) # Seed 고정

# %%
def RUL_metric(y_valid, y_pred, threshold=10):

    error = y_valid.reshape(-1) - y_pred.reshape(-1)
    per = np.where(error<=threshold, 1, 0)
    
    return sum(per) / len(per)

# %%
# sns.set()

# %%
path = "data/Battery_RUL.csv"

# %%
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    Cycle_Index  Discharge Time (s)  Decrement 3.6-3.4V (s)  \
# 0          1.0             2595.30             1151.488500
# 1          2.0             7408.64             1172.512500
# 2          3.0             7393.76             1112.992000
# 3          4.0             7385.50             1080.320667
# 4          6.0            65022.75            29813.487000
#
#    Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)  \
# 0                      3.670                    3.211           5460.001
# 1                      4.246                    3.220           5508.992
# 2                      4.249                    3.224           5508.993
# 3                      4.250                    3.225           5502.016
# 4                      4.290                    3.398           5480.992
#
#    Time constant current (s)  Charging time (s)   RUL
# 0                    6755.01           10777.82  1112
# 1                    6762.02           10500.35  1111
# 2                    6762.02           10420.38  1110
# 3                    6762.02           10322.81  1109
# 4                   53213.54           56699.65  1107

# %%
data.shape
# Out:
# (15064, 9)

# %%
# 다음 컬럼들은 RUL에 관계가 없기 때문에 제거한다.
data=data.drop(['Cycle_Index','Discharge Time (s)', 'Decrement 3.6-3.4V (s)', 'Time constant current (s)','Charging time (s)'],axis=1)

# %%
data.head()
# Out:
#    Max. Voltage Dischar. (V)  Min. Voltage Charg. (V)  Time at 4.15V (s)   RUL
# 0                      3.670                    3.211           5460.001  1112
# 1                      4.246                    3.220           5508.992  1111
# 2                      4.249                    3.224           5508.993  1110
# 3                      4.250                    3.225           5502.016  1109
# 4                      4.290                    3.398           5480.992  1107

# %% [markdown]
# ## Modeling and Predections

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.l1 = nn.Linear(input_size, hidden_size)
        self.l2 = nn.Linear(hidden_size, hidden_size//2)
        self.l3 = nn.Linear(hidden_size//2, hidden_size//2)
        self.l4 = nn.Linear(hidden_size//2, num_classes)
        self.act = nn.ELU()

    def forward(self, x):
        out = self.act(self.l1(x))
        out = self.act(self.l2(out))
        out = self.act(self.l3(out))
        out = self.l4(out)
        return out

# %%
data = data[data['RUL']!=0]

X = data.drop(['RUL'], axis=1)
y = data['RUL']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=2023, shuffle =True)
X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size=0.2, random_state=2023, shuffle =True)

# %%
class Pipeline:
    def __init__(self, scalar):
        self.scalar = scalar
    
    def fit(self, X, y):
        X = self.scalar.fit_transform(X)
        return X, y.to_numpy(dtype=np.float32)
    
    def transform(self, X, y):
        X = self.scalar.transform(X)
        return X, y.to_numpy(dtype=np.float32)

# %%
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler
robust = RobustScaler()
pipeline = Pipeline(robust)

# %%
X_train_s, y_train_s = pipeline.fit(X_train, y_train)

X_val_s, y_val_s = pipeline.transform(X_val, y_val)
X_test_s, y_test_s = pipeline.transform(X_test, y_test)

# %%
X_train_s = torch.FloatTensor(X_train_s)
y_train_s = torch.FloatTensor(y_train_s).unsqueeze(-1)

X_val_s = torch.FloatTensor(X_val_s)
y_val_s = torch.FloatTensor(y_val_s).unsqueeze(-1)

X_test_s = torch.FloatTensor(X_test_s)
y_test_s = torch.FloatTensor(y_test_s).unsqueeze(-1)

# %%
X_train_s.shape, y_train_s.shape, X_val_s.shape, y_val_s.shape, X_test_s.shape, y_test_s.shape
# Out:
# (torch.Size([10535, 3]),
#  torch.Size([10535, 1]),
#  torch.Size([3612, 3]),
#  torch.Size([3612, 1]),
#  torch.Size([903, 3]),
#  torch.Size([903, 1]))

# %%
input_size =  X_train_s.shape[1] #num of columns
hidden_size = 64
num_classes = 1

model = NeuralNet(input_size, hidden_size, num_classes)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.1, weight_decay=1e-5)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min')

# %%
train_loss_list = []
test_loss_list = []
min_diff_dict = {}

targets_list = []
pred_list = []
epoch_list = []
MAE_list= []
RUL_score_list = []
best_MAE = np.inf
best_model = 0
# for epoch in tqdm(range(1, 101)):
for epoch in range(1, 101):
    size = len(X_train_s)
    optimizer.zero_grad()
    outputs = model(X_train_s)
    loss = criterion(outputs, y_train_s)
    loss.backward()
    optimizer.step()
    print(f'Epoch : {epoch} / AVG train loss : {loss.item()/size}')
    train_loss_list.append(loss.item()/size)
    
    with torch.no_grad():
        size = len(X_val_s)
        pred = model(X_val_s)
        test_loss = criterion(pred, y_val_s)
        
        test_loss_list.append(test_loss.item()/size)
        pred_np = pred.squeeze().tolist()
        target_np = y_val_s.squeeze().tolist()
        
        try:
            for i,j in zip(pred_np,target_np):
                pred_list.append(i)
                targets_list.append(j)
        except:
            pass
        
        pred = pred.detach().cpu().numpy()
        y = y_val_s.detach().cpu().numpy()
    
        RMSE = mean_squared_error(y, pred, squared=False)
        MAE = mean_absolute_error(y, pred)
        MAPE = mean_absolute_percentage_error(y, pred)
        R2 = r2_score(y, pred)
        RUL_score = RUL_metric(y, pred, threshold=100)
        msg = f"Test: \n Avg loss: {test_loss.item()/size:>8f}, \n"
        print(msg) 
        msg = f"- RMSE: {(RMSE):>0.2f}, - MAE: {(MAE):>0.2f}, - MAPE: {(MAPE):>0.2f},  - R2: {(R2):>0.2f},  - RUL_metric: {(RUL_score):>0.2f}, \n"
        print(msg)
        print('---'*20)
        
        scheduler.step(test_loss)

    epoch_list.append(epoch)
    MAE_list.append(MAE)
    RUL_score_list.append(RUL_score*100)
    
    mean_MAE = np.mean(MAE_list)
    if mean_MAE < best_MAE:
        best_MAE = mean_MAE
        best_model = model
    
plt.figure(figsize=(10,8))
plt.subplot(3,1,1)
plt.scatter(targets_list, pred_list)
plt.xlabel('Target', fontsize=10)
plt.ylabel('Prediction', fontsize=10)
plt.ylim(0, 1300)
plt.title(f"Epoch {epoch+1}", fontsize=13)

plt.subplot(3,1,2)
# plt.scatter(epoch_list, MAE_list)
plt.plot(MAE_list, label='RUL_score', marker = '.')
plt.ylim(0, 1000)
plt.xlabel('Epoch')
plt.ylabel('Target-Pred MAE')

# PLOT Difference
plt.subplot(3,1,3)
# plt.scatter(epoch_list, RUL_score_list)
plt.plot(RUL_score_list, label='RUL_score', marker = '.')
plt.ylim(0, 100)
plt.xlabel('Epoch')
plt.ylabel('Target-Pred RUL_score (%)')
# plt.scatter(epoch, test_loss)
plt.tight_layout()

plt.savefig(f'./result/training_{epoch}.png')
# Out:
# Epoch : 1 / AVG train loss : 38.996170503084954
# Test:
#  Avg loss: 113.086422,
#
# - RMSE: 639.12, - MAE: 553.47, - MAPE: 1.00,  - R2: -2.99,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 2 / AVG train loss : 38.87170740389179
# Test:
#  Avg loss: 109.549981,
#
# - RMSE: 629.04, - MAE: 543.36, - MAPE: 0.96,  - R2: -2.87,  - RUL_metric: 0.09,
#
# ------------------------------------------------------------
# Epoch : 3 / AVG train loss : 37.637295325106784
# Test:
#  Avg loss: 100.280895,
#
# - RMSE: 601.84, - MAE: 519.11, - MAPE: 0.92,  - R2: -2.54,  - RUL_metric: 0.10,
#
# ------------------------------------------------------------
# Epoch : 4 / AVG train loss : 34.40428630754627
# Test:
#  Avg loss: 80.433096,
#
# - RMSE: 539.00, - MAE: 467.60, - MAPE: 0.88,  - R2: -1.84,  - RUL_metric: 0.11,
#
# ------------------------------------------------------------
# Epoch : 5 / AVG train loss : 27.859744304698623
# Test:
#  Avg loss: 52.238796,
#
# - RMSE: 434.38, - MAE: 367.14, - MAPE: 0.78,  - R2: -0.84,  - RUL_metric: 0.12,
#
# ------------------------------------------------------------
# Epoch : 6 / AVG train loss : 20.21345070004746
# Test:
#  Avg loss: 27.221108,
#
# - RMSE: 313.56, - MAE: 192.76, - MAPE: 0.50,  - R2: 0.04,  - RUL_metric: 0.28,
#
# ------------------------------------------------------------
# Epoch : 7 / AVG train loss : 13.326840590887517
# Test:
#  Avg loss: 10.821971,
#
# - RMSE: 197.71, - MAE: 82.59, - MAPE: 0.37,  - R2: 0.62,  - RUL_metric: 0.89,
#
# ------------------------------------------------------------
# Epoch : 8 / AVG train loss : 5.020859041290935
# Test:
#  Avg loss: 7.068884,
#
# - RMSE: 159.79, - MAE: 124.19, - MAPE: 0.76,  - R2: 0.75,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 9 / AVG train loss : 3.1165219358092076
# Test:
#  Avg loss: 8.748381,
#
# - RMSE: 177.76, - MAE: 123.84, - MAPE: 0.87,  - R2: 0.69,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 10 / AVG train loss : 4.210919702183199
# Test:
#  Avg loss: 5.974039,
#
# - RMSE: 146.90, - MAE: 106.21, - MAPE: 0.63,  - R2: 0.79,  - RUL_metric: 0.78,
#
# ------------------------------------------------------------
# Epoch : 11 / AVG train loss : 2.6209024234693876
# Test:
#  Avg loss: 5.855289,
#
# - RMSE: 145.43, - MAE: 105.74, - MAPE: 0.42,  - R2: 0.79,  - RUL_metric: 0.68,
#
# ------------------------------------------------------------
# Epoch : 12 / AVG train loss : 2.3387271223896535
# Test:
#  Avg loss: 5.166535,
#
# - RMSE: 136.61, - MAE: 97.37, - MAPE: 0.32,  - R2: 0.82,  - RUL_metric: 0.67,
#
# ------------------------------------------------------------
# Epoch : 13 / AVG train loss : 2.03546622864262
# Test:
#  Avg loss: 4.220702,
#
# - RMSE: 123.47, - MAE: 87.67, - MAPE: 0.33,  - R2: 0.85,  - RUL_metric: 0.80,
#
# ------------------------------------------------------------
# Epoch : 14 / AVG train loss : 1.6952739380635975
# Test:
#  Avg loss: 5.048420,
#
# - RMSE: 135.04, - MAE: 98.46, - MAPE: 0.37,  - R2: 0.82,  - RUL_metric: 0.86,
#
# ------------------------------------------------------------
# Epoch : 15 / AVG train loss : 1.954361948267679
# Test:
#  Avg loss: 4.966448,
#
# - RMSE: 133.94, - MAE: 98.87, - MAPE: 0.37,  - R2: 0.82,  - RUL_metric: 0.85,
#
# ------------------------------------------------------------
# Epoch : 16 / AVG train loss : 1.8950388585666824
# Test:
#  Avg loss: 3.795567,
#
# - RMSE: 117.09, - MAE: 85.18, - MAPE: 0.37,  - R2: 0.87,  - RUL_metric: 0.81,
#
# ------------------------------------------------------------
# Epoch : 17 / AVG train loss : 1.4616222524620313
# Test:
#  Avg loss: 4.014231,
#
# - RMSE: 120.41, - MAE: 90.78, - MAPE: 0.42,  - R2: 0.86,  - RUL_metric: 0.67,
#
# ------------------------------------------------------------
# Epoch : 18 / AVG train loss : 1.5064975935868534
# Test:
#  Avg loss: 3.672737,
#
# - RMSE: 115.18, - MAE: 87.90, - MAPE: 0.46,  - R2: 0.87,  - RUL_metric: 0.69,
#
# ------------------------------------------------------------
# Epoch : 19 / AVG train loss : 1.3851876742702895
# Test:
#  Avg loss: 2.950592,
#
# - RMSE: 103.24, - MAE: 78.63, - MAPE: 0.51,  - R2: 0.90,  - RUL_metric: 0.79,
#
# ------------------------------------------------------------
# Epoch : 20 / AVG train loss : 1.1969321013289036
# Test:
#  Avg loss: 3.123580,
#
# - RMSE: 106.22, - MAE: 79.34, - MAPE: 0.57,  - R2: 0.89,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 21 / AVG train loss : 1.3004865663561935
# Test:
#  Avg loss: 3.270564,
#
# - RMSE: 108.69, - MAE: 82.37, - MAPE: 0.62,  - R2: 0.88,  - RUL_metric: 0.94,
#
# ------------------------------------------------------------
# Epoch : 22 / AVG train loss : 1.3249771038502611
# Test:
#  Avg loss: 2.575493,
#
# - RMSE: 96.45, - MAE: 74.86, - MAPE: 0.63,  - R2: 0.91,  - RUL_metric: 0.91,
#
# ------------------------------------------------------------
# Epoch : 23 / AVG train loss : 1.0336442698445658
# Test:
#  Avg loss: 2.718252,
#
# - RMSE: 99.09, - MAE: 77.41, - MAPE: 0.64,  - R2: 0.90,  - RUL_metric: 0.79,
#
# ------------------------------------------------------------
# Epoch : 24 / AVG train loss : 1.040736792536782
# Test:
#  Avg loss: 2.966561,
#
# - RMSE: 103.51, - MAE: 79.68, - MAPE: 0.65,  - R2: 0.90,  - RUL_metric: 0.77,
#
# ------------------------------------------------------------
# Epoch : 25 / AVG train loss : 1.1096964730659706
# Test:
#  Avg loss: 2.572523,
#
# - RMSE: 96.39, - MAE: 74.05, - MAPE: 0.63,  - R2: 0.91,  - RUL_metric: 0.84,
#
# ------------------------------------------------------------
# Epoch : 26 / AVG train loss : 0.9768817483388704
# Test:
#  Avg loss: 2.521822,
#
# - RMSE: 95.44, - MAE: 70.81, - MAPE: 0.60,  - R2: 0.91,  - RUL_metric: 0.93,
#
# ------------------------------------------------------------
# Epoch : 27 / AVG train loss : 0.9669560356846227
# Test:
#  Avg loss: 2.652371,
#
# - RMSE: 97.88, - MAE: 71.27, - MAPE: 0.53,  - R2: 0.91,  - RUL_metric: 0.94,
#
# ------------------------------------------------------------
# Epoch : 28 / AVG train loss : 1.0165175790519696
# Test:
#  Avg loss: 2.274911,
#
# - RMSE: 90.65, - MAE: 63.84, - MAPE: 0.42,  - R2: 0.92,  - RUL_metric: 0.91,
#
# ------------------------------------------------------------
# Epoch : 29 / AVG train loss : 0.8879644117821547
# Test:
#  Avg loss: 2.261024,
#
# - RMSE: 90.37, - MAE: 64.63, - MAPE: 0.36,  - R2: 0.92,  - RUL_metric: 0.85,
#
# ------------------------------------------------------------
# Epoch : 30 / AVG train loss : 0.8813453851744186
# Test:
#  Avg loss: 2.318805,
#
# - RMSE: 91.52, - MAE: 66.35, - MAPE: 0.36,  - R2: 0.92,  - RUL_metric: 0.82,
#
# ------------------------------------------------------------
# Epoch : 31 / AVG train loss : 0.8994433547401519
# Test:
#  Avg loss: 1.951624,
#
# - RMSE: 83.96, - MAE: 60.84, - MAPE: 0.41,  - R2: 0.93,  - RUL_metric: 0.88,
#
# ------------------------------------------------------------
# Epoch : 32 / AVG train loss : 0.7753644844565734
# Test:
#  Avg loss: 1.838588,
#
# - RMSE: 81.49, - MAE: 59.54, - MAPE: 0.49,  - R2: 0.94,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 33 / AVG train loss : 0.745089888244542
# Test:
#  Avg loss: 1.909309,
#
# - RMSE: 83.04, - MAE: 62.64, - MAPE: 0.58,  - R2: 0.93,  - RUL_metric: 0.94,
#
# ------------------------------------------------------------
# Epoch : 34 / AVG train loss : 0.7854662286426198
# Test:
#  Avg loss: 1.731653,
#
# - RMSE: 79.09, - MAE: 59.21, - MAPE: 0.62,  - R2: 0.94,  - RUL_metric: 0.93,
#
# ------------------------------------------------------------
# Epoch : 35 / AVG train loss : 0.7414574187233033
# Test:
#  Avg loss: 1.755361,
#
# - RMSE: 79.63, - MAE: 60.03, - MAPE: 0.61,  - R2: 0.94,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 36 / AVG train loss : 0.7549755558109872
# Test:
#  Avg loss: 1.689458,
#
# - RMSE: 78.12, - MAE: 58.38, - MAPE: 0.52,  - R2: 0.94,  - RUL_metric: 0.90,
#
# ------------------------------------------------------------
# Epoch : 37 / AVG train loss : 0.7227156224044851
# Test:
#  Avg loss: 1.522722,
#
# - RMSE: 74.16, - MAE: 53.64, - MAPE: 0.41,  - R2: 0.95,  - RUL_metric: 0.91,
#
# ------------------------------------------------------------
# Epoch : 38 / AVG train loss : 0.647754462431775
# Test:
#  Avg loss: 1.594622,
#
# - RMSE: 75.89, - MAE: 54.97, - MAPE: 0.34,  - R2: 0.94,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 39 / AVG train loss : 0.6570458034231135
# Test:
#  Avg loss: 1.602240,
#
# - RMSE: 76.07, - MAE: 54.43, - MAPE: 0.32,  - R2: 0.94,  - RUL_metric: 0.91,
#
# ------------------------------------------------------------
# Epoch : 40 / AVG train loss : 0.6499936502580683
# Test:
#  Avg loss: 1.567369,
#
# - RMSE: 75.24, - MAE: 52.24, - MAPE: 0.32,  - R2: 0.94,  - RUL_metric: 0.91,
#
# ------------------------------------------------------------
# Epoch : 41 / AVG train loss : 0.6329266099608448
# Test:
#  Avg loss: 1.574245,
#
# - RMSE: 75.41, - MAE: 54.06, - MAPE: 0.37,  - R2: 0.94,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 42 / AVG train loss : 0.6292478846553156
# Test:
#  Avg loss: 1.521572,
#
# - RMSE: 74.13, - MAE: 53.67, - MAPE: 0.42,  - R2: 0.95,  - RUL_metric: 0.94,
#
# ------------------------------------------------------------
# Epoch : 43 / AVG train loss : 0.608114089567513
# Test:
#  Avg loss: 1.459998,
#
# - RMSE: 72.62, - MAE: 51.72, - MAPE: 0.41,  - R2: 0.95,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 44 / AVG train loss : 0.5840846731134314
# Test:
#  Avg loss: 1.431461,
#
# - RMSE: 71.91, - MAE: 51.60, - MAPE: 0.36,  - R2: 0.95,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 45 / AVG train loss : 0.5738337795147128
# Test:
#  Avg loss: 1.361056,
#
# - RMSE: 70.12, - MAE: 48.98, - MAPE: 0.32,  - R2: 0.95,  - RUL_metric: 0.93,
#
# ------------------------------------------------------------
# Epoch : 46 / AVG train loss : 0.5525876357083531
# Test:
#  Avg loss: 1.360799,
#
# - RMSE: 70.11, - MAE: 49.42, - MAPE: 0.31,  - R2: 0.95,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 47 / AVG train loss : 0.5585883735761746
# Test:
#  Avg loss: 1.313719,
#
# - RMSE: 68.89, - MAE: 48.93, - MAPE: 0.34,  - R2: 0.95,  - RUL_metric: 0.92,
#
# ------------------------------------------------------------
# Epoch : 48 / AVG train loss : 0.5481930581098718
# Test:
#  Avg loss: 1.250398,
#
# - RMSE: 67.20, - MAE: 47.14, - MAPE: 0.38,  - R2: 0.96,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 49 / AVG train loss : 0.5276751879894399
# Test:
#  Avg loss: 1.281201,
#
# - RMSE: 68.03, - MAE: 48.43, - MAPE: 0.42,  - R2: 0.95,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 50 / AVG train loss : 0.536038632386094
# Test:
#  Avg loss: 1.230297,
#
# - RMSE: 66.66, - MAE: 46.53, - MAPE: 0.41,  - R2: 0.96,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 51 / AVG train loss : 0.5160705479502847
# Test:
#  Avg loss: 1.206559,
#
# - RMSE: 66.02, - MAE: 45.54, - MAPE: 0.38,  - R2: 0.96,  - RUL_metric: 0.94,
#
# ------------------------------------------------------------
# Epoch : 52 / AVG train loss : 0.5046495405938538
# Test:
#  Avg loss: 1.215637,
#
# - RMSE: 66.26, - MAE: 45.32, - MAPE: 0.34,  - R2: 0.96,  - RUL_metric: 0.93,
#
# ------------------------------------------------------------
# Epoch : 53 / AVG train loss : 0.5034074012962744
# Test:
#  Avg loss: 1.188674,
#
# - RMSE: 65.52, - MAE: 44.23, - MAPE: 0.33,  - R2: 0.96,  - RUL_metric: 0.93,
#
# ------------------------------------------------------------
# Epoch : 54 / AVG train loss : 0.49008346434504035
# Test:
#  Avg loss: 1.189014,
#
# - RMSE: 65.53, - MAE: 45.21, - MAPE: 0.34,  - R2: 0.96,  - RUL_metric: 0.94,
#
# ------------------------------------------------------------
# Epoch : 55 / AVG train loss : 0.48759339218972475
# Test:
#  Avg loss: 1.151580,
#
# - RMSE: 64.49, - MAE: 43.78, - MAPE: 0.36,  - R2: 0.96,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 56 / AVG train loss : 0.47315264223421927
# Test:
#  Avg loss: 1.135944,
#
# - RMSE: 64.05, - MAE: 44.09, - MAPE: 0.37,  - R2: 0.96,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 57 / AVG train loss : 0.4672725494630992
# Test:
#  Avg loss: 1.092620,
#
# - RMSE: 62.82, - MAE: 42.77, - MAPE: 0.34,  - R2: 0.96,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 58 / AVG train loss : 0.45455549952539154
# Test:
#  Avg loss: 1.072696,
#
# - RMSE: 62.25, - MAE: 42.40, - MAPE: 0.32,  - R2: 0.96,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 59 / AVG train loss : 0.4500647488283104
# Test:
#  Avg loss: 1.058373,
#
# - RMSE: 61.83, - MAE: 42.77, - MAPE: 0.32,  - R2: 0.96,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 60 / AVG train loss : 0.44395115240863786
# Test:
#  Avg loss: 1.021519,
#
# - RMSE: 60.74, - MAE: 41.60, - MAPE: 0.32,  - R2: 0.96,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 61 / AVG train loss : 0.42816180069411486
# Test:
#  Avg loss: 1.036924,
#
# - RMSE: 61.20, - MAE: 42.98, - MAPE: 0.32,  - R2: 0.96,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 62 / AVG train loss : 0.43005050130517325
# Test:
#  Avg loss: 1.015225,
#
# - RMSE: 60.56, - MAE: 41.72, - MAPE: 0.31,  - R2: 0.96,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 63 / AVG train loss : 0.4198357131733507
# Test:
#  Avg loss: 1.011499,
#
# - RMSE: 60.44, - MAE: 41.29, - MAPE: 0.30,  - R2: 0.96,  - RUL_metric: 0.94,
#
# ------------------------------------------------------------
# Epoch : 64 / AVG train loss : 0.4166036481816564
# Test:
#  Avg loss: 0.990058,
#
# - RMSE: 59.80, - MAE: 40.71, - MAPE: 0.31,  - R2: 0.97,  - RUL_metric: 0.94,
#
# ------------------------------------------------------------
# Epoch : 65 / AVG train loss : 0.40880241086260083
# Test:
#  Avg loss: 0.976033,
#
# - RMSE: 59.38, - MAE: 40.79, - MAPE: 0.34,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 66 / AVG train loss : 0.40280862526696726
# Test:
#  Avg loss: 0.973993,
#
# - RMSE: 59.31, - MAE: 41.14, - MAPE: 0.37,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 67 / AVG train loss : 0.39908359782866637
# Test:
#  Avg loss: 0.970397,
#
# - RMSE: 59.20, - MAE: 41.23, - MAPE: 0.38,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 68 / AVG train loss : 0.39495000852812057
# Test:
#  Avg loss: 0.965110,
#
# - RMSE: 59.04, - MAE: 41.29, - MAPE: 0.38,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 69 / AVG train loss : 0.391355127625178
# Test:
#  Avg loss: 0.951104,
#
# - RMSE: 58.61, - MAE: 40.50, - MAPE: 0.37,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 70 / AVG train loss : 0.3843136346108211
# Test:
#  Avg loss: 0.942979,
#
# - RMSE: 58.36, - MAE: 40.38, - MAPE: 0.38,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 71 / AVG train loss : 0.3803416161159231
# Test:
#  Avg loss: 0.928689,
#
# - RMSE: 57.92, - MAE: 40.38, - MAPE: 0.40,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 72 / AVG train loss : 0.37425962936046514
# Test:
#  Avg loss: 0.934929,
#
# - RMSE: 58.11, - MAE: 40.80, - MAPE: 0.41,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 73 / AVG train loss : 0.3747165558628975
# Test:
#  Avg loss: 0.918937,
#
# - RMSE: 57.61, - MAE: 40.20, - MAPE: 0.40,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 74 / AVG train loss : 0.36709172086349073
# Test:
#  Avg loss: 0.918907,
#
# - RMSE: 57.61, - MAE: 40.09, - MAPE: 0.39,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 75 / AVG train loss : 0.3647370094476744
# Test:
#  Avg loss: 0.907257,
#
# - RMSE: 57.25, - MAE: 40.16, - MAPE: 0.40,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 76 / AVG train loss : 0.35858450347799004
# Test:
#  Avg loss: 0.903064,
#
# - RMSE: 57.11, - MAE: 40.56, - MAPE: 0.41,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 77 / AVG train loss : 0.35603538335755813
# Test:
#  Avg loss: 0.892140,
#
# - RMSE: 56.77, - MAE: 40.07, - MAPE: 0.41,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 78 / AVG train loss : 0.35206341121114143
# Test:
#  Avg loss: 0.883516,
#
# - RMSE: 56.49, - MAE: 39.73, - MAPE: 0.39,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 79 / AVG train loss : 0.34867816448890604
# Test:
#  Avg loss: 0.877435,
#
# - RMSE: 56.30, - MAE: 39.61, - MAPE: 0.37,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 80 / AVG train loss : 0.3442666928690081
# Test:
#  Avg loss: 0.879849,
#
# - RMSE: 56.37, - MAE: 39.84, - MAPE: 0.37,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 81 / AVG train loss : 0.3417546978820598
# Test:
#  Avg loss: 0.877298,
#
# - RMSE: 56.29, - MAE: 39.60, - MAPE: 0.37,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 82 / AVG train loss : 0.33882767541973186
# Test:
#  Avg loss: 0.872421,
#
# - RMSE: 56.14, - MAE: 39.48, - MAPE: 0.37,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 83 / AVG train loss : 0.33646849137547463
# Test:
#  Avg loss: 0.862454,
#
# - RMSE: 55.81, - MAE: 39.27, - MAPE: 0.35,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 84 / AVG train loss : 0.3327742625029663
# Test:
#  Avg loss: 0.861324,
#
# - RMSE: 55.78, - MAE: 39.48, - MAPE: 0.35,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 85 / AVG train loss : 0.33160129831365687
# Test:
#  Avg loss: 0.857123,
#
# - RMSE: 55.64, - MAE: 39.23, - MAPE: 0.36,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 86 / AVG train loss : 0.3287691280182131
# Test:
#  Avg loss: 0.859026,
#
# - RMSE: 55.70, - MAE: 39.21, - MAPE: 0.36,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 87 / AVG train loss : 0.32774561450670386
# Test:
#  Avg loss: 0.854252,
#
# - RMSE: 55.55, - MAE: 39.14, - MAPE: 0.34,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 88 / AVG train loss : 0.3248616729577005
# Test:
#  Avg loss: 0.852012,
#
# - RMSE: 55.47, - MAE: 39.03, - MAPE: 0.34,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 89 / AVG train loss : 0.32352475101595873
# Test:
#  Avg loss: 0.845231,
#
# - RMSE: 55.25, - MAE: 38.70, - MAPE: 0.34,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 90 / AVG train loss : 0.3207156622641789
# Test:
#  Avg loss: 0.841415,
#
# - RMSE: 55.13, - MAE: 38.70, - MAPE: 0.34,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 91 / AVG train loss : 0.3190229462060987
# Test:
#  Avg loss: 0.834838,
#
# - RMSE: 54.91, - MAE: 38.62, - MAPE: 0.34,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 92 / AVG train loss : 0.3159038788116991
# Test:
#  Avg loss: 0.830742,
#
# - RMSE: 54.78, - MAE: 38.52, - MAPE: 0.33,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 93 / AVG train loss : 0.31437725253618887
# Test:
#  Avg loss: 0.825005,
#
# - RMSE: 54.59, - MAE: 38.39, - MAPE: 0.33,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 94 / AVG train loss : 0.31227532573712624
# Test:
#  Avg loss: 0.821788,
#
# - RMSE: 54.48, - MAE: 38.40, - MAPE: 0.34,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 95 / AVG train loss : 0.31102085774353344
# Test:
#  Avg loss: 0.818545,
#
# - RMSE: 54.37, - MAE: 38.34, - MAPE: 0.34,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 96 / AVG train loss : 0.30920571217222353
# Test:
#  Avg loss: 0.816664,
#
# - RMSE: 54.31, - MAE: 38.13, - MAPE: 0.32,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 97 / AVG train loss : 0.3075989725468676
# Test:
#  Avg loss: 0.813548,
#
# - RMSE: 54.21, - MAE: 38.07, - MAPE: 0.33,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 98 / AVG train loss : 0.3062243692898671
# Test:
#  Avg loss: 0.807608,
#
# - RMSE: 54.01, - MAE: 38.10, - MAPE: 0.34,  - R2: 0.97,  - RUL_metric: 0.96,
#
# ------------------------------------------------------------
# Epoch : 99 / AVG train loss : 0.3048321072615093
# Test:
#  Avg loss: 0.797806,
#
# - RMSE: 53.68, - MAE: 37.90, - MAPE: 0.33,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------
# Epoch : 100 / AVG train loss : 0.3017206178437945
# Test:
#  Avg loss: 0.794283,
#
# - RMSE: 53.56, - MAE: 37.79, - MAPE: 0.32,  - R2: 0.97,  - RUL_metric: 0.95,
#
# ------------------------------------------------------------

# %%
# 함수로 만들어서 사용합시다.
def dl_history_plot(train_loss_list, test_loss_list):
    plt.figure(figsize=(10,6))
    plt.plot(train_loss_list, label='train_err', marker = '.')
    plt.plot(test_loss_list, label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()
    
dl_history_plot(train_loss_list, test_loss_list)

# %%
def visualization_result(y_val,pred, size=100):
  sns.lineplot(y_val[:size], label='valid train')
  sns.lineplot(pred.reshape(pred.shape[0],)[:size], label='pred')
  plt.legend(loc='upper right')
  plt.show()

# %%
pred = best_model(X_test_s)

# %%
pred = pred.detach().cpu().numpy()
y_test_s = y_test_s.detach().cpu().numpy()

# %%
from sklearn.metrics import * 

def RUL_metric(y_valid, y_pred, threshold=10):

    error = y_valid.reshape(-1) - y_pred.reshape(-1)
    per = np.where(error<=threshold, 1, 0)
    
    return sum(per) / len(per)

print(f'RMSE : {mean_squared_error(y_test_s, pred, squared=False)}')
print(f'MAE  : {mean_absolute_error(y_test_s, pred)}')
print(f'MAPE : {mean_absolute_percentage_error(y_test_s, pred)}')
print(f'R2 : {r2_score(y_test_s, pred)}')
print(f'RUL_metric : {RUL_metric(y_test_s, pred, threshold=100)}')
# Out:
# RMSE : 53.79196548461914
# MAE  : 38.40317153930664
# MAPE : 0.2850157916545868
# R2 : 0.9718145958969576
# RUL_metric : 0.9501661129568106

# %%
def visualization_result(y_val,pred, size=100):
  y_val = y_val.reshape(y_val.shape[0],)
  pred = pred.reshape(pred.shape[0],)
  sns.lineplot(y_val[:size], label='actual RUL')
  sns.lineplot(pred[:size], label='pred RUL')
  plt.legend()
  plt.show()

# %%
visualization_result(y_test_s,pred, size=100)

# %%
'''
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.l1 = nn.Linear(input_size, hidden_size)
        self.l2 = nn.Linear(hidden_size, num_classes)
        self.act = nn.ELU()

    def forward(self, x):
        out = self.l1(x)
        out = self.act(out)
        out = self.l2(out)
        return out

일 경우 
RMSE : 122.64473724365234
MAE  : 93.70903778076172
MAPE : 0.5671193599700928
R2 : 0.8534832507200503
RUL_metric : 0.8748615725359912


class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.l1 = nn.Linear(input_size, hidden_size)
        self.l2 = nn.Linear(hidden_size, hidden_size)
        self.l3 = nn.Linear(hidden_size, num_classes)
        self.act = nn.ELU()
        self.Drop = nn.Dropout(p=0.25)

    def forward(self, x):
        out = self.l1(x)
        out = self.act(out)
        out = self.l2(out)
        out = self.act(out)
        out = self.l3(out)
        return out

RMSE : 73.60551452636719
MAE  : 51.06753158569336
MAPE : 0.33087578415870667
R2 : 0.9472272048922442
RUL_metric : 0.9258028792912514

'''
